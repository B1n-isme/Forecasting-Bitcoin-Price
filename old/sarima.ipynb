# %%
import json
import pandas as pd
import pandas as pd
from pmdarima import auto_arima
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# %%
df = pd.read_csv("../data/final/dataset.csv", parse_dates=["Date"], index_col="Date")

# Define the list of technical indicators
technical_features = [
    'btc_sma_14',
    'btc_ema_14', 'btc_rsi_14', 'btc_macd', 'btc_macd_signal',
    'btc_macd_diff', 'btc_bb_high', 'btc_bb_low', 'btc_bb_mid',
    'btc_bb_width', 'btc_atr_14', 'btc_trading_volume',
    'btc_volatility_index'
]

non_technical_features = [col for col in df.columns if col not in [technical_features, 'btc_close']]

# %%
from statsmodels.tsa.stattools import adfuller

# Function to perform ADF test and determine d
def find_d_value(series, max_d=5):
    d = 0
    for i in range(max_d + 1):
        if i == 0:
            test_series = series
        else:
            test_series = series.diff(i).dropna()
        
        result = adfuller(test_series)
        p_value = result[1]
        
        if p_value <= 0.05:
            print(f"Column '{series.name}' is stationary after {i} differences (d = {i})")
            return i
    print(f"Column '{series.name}' could not be made stationary within {max_d} differences")
    return max_d

# Dictionary to store d values for each column
d_values = {}

# Loop through each non-technical feature column and find d value
for column in non_technical_features:
    d_value = find_d_value(df[column])
    d_values[column] = d_value

# Print the dictionary
print("d values for each column:")
print(d_values)
# Out:
# Column 'google_trends_bitcoin' is stationary after 0 differences (d = 0)
# Column 'active_addresses_blockchain' is stationary after 1 differences (d = 1)
# Column 'hash_rate_blockchain' is stationary after 1 differences (d = 1)
# Column 'miner_revenue_blockchain' is stationary after 1 differences (d = 1)
# Column 'Gold_Close' is stationary after 1 differences (d = 1)
# Column 'Oil_Close' is stationary after 1 differences (d = 1)
# Column 'DJI' is stationary after 1 differences (d = 1)
# Column 'GSPC' is stationary after 1 differences (d = 1)
# Column 'IXIC' is stationary after 1 differences (d = 1)
# Column 'NYSE FANG+' is stationary after 1 differences (d = 1)
# Column 'ARK Innovation ETF' is stationary after 1 differences (d = 1)
# Column 'CBOE Volatility Index' is stationary after 0 differences (d = 0)
# Column 'iShares MSCI Emerging Markets ETF' is stationary after 1 differences (d = 1)
# Column 'Shanghai Composite Index' is stationary after 0 differences (d = 0)
# Column 'USD Index (DXY)' is stationary after 1 differences (d = 1)
# Column 'EUR to USD Exchange Rate' is stationary after 0 differences (d = 0)
# Column 'btc_close' is stationary after 1 differences (d = 1)
# d values for each column:
# {'google_trends_bitcoin': 0, 'active_addresses_blockchain': 1, 'hash_rate_blockchain': 1, 'miner_revenue_blockchain': 1, 'Gold_Close': 1, 'Oil_Close': 1, 'DJI': 1, 'GSPC': 1, 'IXIC': 1, 'NYSE FANG+': 1, 'ARK Innovation ETF': 1, 'CBOE Volatility Index': 0, 'iShares MSCI Emerging Markets ETF': 1, 'Shanghai Composite Index': 0, 'USD Index (DXY)': 1, 'EUR to USD Exchange Rate': 0, 'btc_close': 1}

# %%
# Function to fit auto_arima and return the model
def fit_auto_arima(series, seasonal_period=12):
    model = auto_arima(
        series,
        seasonal=True,
        m=seasonal_period,  # Seasonality (e.g., 12 for monthly data)
        max_p=3, max_d=1, max_q=3,  # Non-seasonal order limits
        max_P=2, max_D=1, max_Q=2,  # Seasonal order limits
        trace=True,  # Print progress
        error_action='ignore',  # Ignore fitting errors
        suppress_warnings=True
    )
    return model

# Function to process each column in parallel
def process_column(column_name, series, seasonal_period=12):
    print(f"Processing column: {column_name}")
    model = fit_auto_arima(series, seasonal_period)
    print(f"Best SARIMA parameters for {column_name}: {model.order}, {model.seasonal_order}")
    return {
        'column': column_name,
        'order': model.order,
        'seasonal_order': model.seasonal_order,
        'model': model
    }

# Seasonal period (set based on your data's seasonality)
seasonal_period = 12  # Example: 12 for monthly data with yearly seasonality

# Process all columns in parallel
results = Parallel(n_jobs=-1)(
    delayed(process_column)(column, df[column], seasonal_period)
    for column in non_technical_features
)

# Store results in a dictionary
sarima_params = {result['column']: result for result in results}

# Print the results
print("\nSARIMA parameters for each column:")
for column, result in sarima_params.items():
    print(f"Column: {column}")
    print(f"Order: {result['order']}")
    print(f"Seasonal Order: {result['seasonal_order']}")
    print(f"Model AIC: {result['model'].aic}")
    print("------")
# Out:
# Processing column: DJI
# Processing column: IXIC
# Processing column: ARK Innovation ETF
# Processing column: active_addresses_blockchain
# Processing column: GSPC
# Processing column: miner_revenue_blockchain
# Processing column: NYSE FANG+
# Processing column: google_trends_bitcoin
# Processing column: Gold_Close
# Processing column: Oil_Close
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Processing column: hash_rate_blockchain
# Performing stepwise search to minimize aic
# Processing column: CBOE Volatility Index
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=14472.728, Time=1.43 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=14663.584, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=14493.604, Time=0.35 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=14470.100, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=14661.590, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=14469.892, Time=0.10 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=14470.113, Time=0.37 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=11806.098, Time=3.00 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=11804.668, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=14472.134, Time=0.58 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=29015.001, Time=3.42 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=11806.787, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=29015.295, Time=0.04 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=119192.762, Time=3.52 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=14466.777, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=120019.515, Time=0.04 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=89356.840, Time=3.57 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=90853.764, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=29014.219, Time=0.32 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=119396.319, Time=0.39 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=90477.656, Time=0.37 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=11806.883, Time=0.54 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=11802.869, Time=0.04 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=11804.825, Time=0.36 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=14466.769, Time=0.97 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=119194.874, Time=0.55 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=120017.565, Time=0.03 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=4.65 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=89975.984, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=29014.175, Time=0.93 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=90851.773, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=29016.463, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=135790.468, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=11804.916, Time=0.39 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=13643.647, Time=4.83 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=13712.463, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=29012.446, Time=0.16 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=134783.213, Time=0.50 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=50421.786, Time=5.25 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=50440.074, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=13646.912, Time=0.41 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=29014.204, Time=0.65 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=50420.208, Time=0.54 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=13642.103, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=13710.464, Time=0.04 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=11803.319, Time=1.14 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=133908.132, Time=0.74 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=45167.113, Time=5.99 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=42071.420, Time=6.00 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=135788.680, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=13647.416, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=42077.917, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=45179.017, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=133908.945, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=11806.664, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=11806.664, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=42077.540, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=50421.296, Time=0.54 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=45166.600, Time=0.37 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=50441.215, Time=0.03 sec
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=27562.276, Time=6.47 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=50425.831, Time=0.08 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=31714.936, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=11806.472, Time=0.37 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 6.636 seconds
# Best SARIMA parameters for ARK Innovation ETF: (0, 1, 0), (0, 0, 0, 12)
# Processing column: iShares MSCI Emerging Markets ETF
# Performing stepwise search to minimize aic
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=42077.314, Time=0.44 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=45166.583, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=42081.684, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=45180.913, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=45164.911, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=119197.523, Time=2.47 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=14468.746, Time=2.59 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=45166.554, Time=0.32 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=35377.046, Time=7.27 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=35400.166, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=29009.007, Time=1.90 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=13643.311, Time=1.59 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=35383.698, Time=0.36 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=89354.848, Time=2.97 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(1,1,0)(2,0,0)[12] intercept   : AIC=50419.960, Time=1.48 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=27661.794, Time=1.76 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=14468.784, Time=1.23 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=35384.130, Time=0.82 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=89543.147, Time=0.82 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=35402.412, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=14466.757, Time=0.86 sec
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=13643.883, Time=1.61 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=29141.986, Time=1.00 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=41234.463, Time=0.01 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=13642.225, Time=0.33 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=119197.590, Time=2.64 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=45165.191, Time=2.42 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=45166.896, Time=0.13 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=45166.904, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=45164.919, Time=0.04 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=4380.697, Time=3.34 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=45168.904, Time=0.22 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=4389.838, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=45167.375, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12] intercept
# Total fit time: 10.289 seconds
# Best SARIMA parameters for IXIC: (0, 1, 1), (0, 0, 0, 12)
#  ARIMA(0,1,1)(0,0,2)[12] intercept   : AIC=133910.100, Time=2.52 sec
# Processing column: Shanghai Composite Index
# Performing stepwise search to minimize aic
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=4373.951, Time=0.41 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=133904.984, Time=0.45 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=4374.041, Time=0.70 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=4387.841, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=4373.484, Time=0.05 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=29004.463, Time=4.24 sec
#  ARIMA(1,1,0)(2,0,1)[12] intercept   : AIC=50421.535, Time=3.90 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=13645.991, Time=2.47 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=4373.988, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=13702.984, Time=0.30 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=42076.681, Time=5.51 sec
#  ARIMA(1,1,1)(0,0,2)[12] intercept   : AIC=14468.714, Time=3.23 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=133905.745, Time=1.96 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=50419.819, Time=1.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=50420.581, Time=0.31 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=13642.191, Time=1.12 sec
#  ARIMA(0,1,1)(2,0,0)[12] intercept   : AIC=29006.440, Time=1.98 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=4374.931, Time=1.63 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=4375.483, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=13641.577, Time=0.55 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=35376.913, Time=5.53 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=4375.483, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=13647.517, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=4373.576, Time=0.13 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=27544.690, Time=5.05 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=4377.484, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=4371.488, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=4371.955, Time=0.19 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=42079.365, Time=2.44 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=4371.992, Time=0.27 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=27549.158, Time=0.92 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=35381.933, Time=1.48 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=4372.935, Time=0.61 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=4373.487, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=4373.487, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=4371.580, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=4375.488, Time=0.12 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12]
# Total fit time: 9.105 seconds
# Best SARIMA parameters for iShares MSCI Emerging Markets ETF: (1, 1, 0), (0, 0, 0, 12)
# Processing column: USD Index (DXY)
# Performing stepwise search to minimize aic
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=13642.591, Time=1.87 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=89355.490, Time=8.11 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=14470.755, Time=4.28 sec
#  ARIMA(1,1,0)(1,0,2)[12] intercept   : AIC=50421.564, Time=3.83 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=14493.591, Time=0.36 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=13643.319, Time=1.68 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=36595.877, Time=7.61 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=36647.709, Time=0.03 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=13641.721, Time=0.45 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=14468.569, Time=1.23 sec
#  ARIMA(1,1,0)(0,0,2)[12] intercept   : AIC=50420.224, Time=1.36 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=36638.995, Time=0.79 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=89365.130, Time=2.36 sec
#  ARIMA(0,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=6.59 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=135780.748, Time=0.17 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=36638.616, Time=0.87 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=36645.858, Time=0.03 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=133903.407, Time=0.74 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=133907.372, Time=0.19 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=13645.449, Time=2.33 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=14468.454, Time=2.48 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=14663.412, Time=0.31 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=14467.094, Time=0.60 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=50423.411, Time=3.56 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=14471.468, Time=0.44 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=2893.135, Time=6.26 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=119194.066, Time=12.59 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=2901.217, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=13634.408, Time=2.16 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=50429.655, Time=0.99 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=2901.783, Time=0.62 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=13637.104, Time=0.51 sec
#  ARIMA(1,1,1)(2,0,0)[12] intercept   : AIC=133904.132, Time=2.75 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=14470.704, Time=1.41 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=2901.803, Time=0.70 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=2899.994, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=14464.769, Time=0.34 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=14464.789, Time=0.09 sec
#  ARIMA(1,1,1)(1,0,1)[12]             : AIC=14466.796, Time=0.44 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=50419.014, Time=1.51 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=36594.996, Time=5.21 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=50419.719, Time=0.49 sec
#  ARIMA(1,1,1)(0,0,2)[12]             : AIC=14466.726, Time=0.98 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=50419.394, Time=0.56 sec
#  ARIMA(1,1,1)(1,0,0)[12]             : AIC=14464.781, Time=0.41 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.67 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=36604.921, Time=1.46 sec
#  ARIMA(1,1,1)(0,0,1)[12] intercept   : AIC=133906.601, Time=0.89 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=29003.917, Time=13.34 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=14468.767, Time=1.42 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=13635.097, Time=4.23 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=14468.111, Time=0.17 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=14491.600, Time=0.18 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=14466.581, Time=0.53 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=14466.467, Time=1.04 sec
#  ARIMA(0,1,0)(0,0,1)[12]             : AIC=14661.419, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=14465.106, Time=0.26 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=inf, Time=5.70 sec
#  ARIMA(2,1,0)(0,0,1)[12]             : AIC=14469.479, Time=0.20 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=11.13 sec
#  ARIMA(2,1,2)(0,0,1)[12]             : AIC=14468.716, Time=0.63 sec
#
# Best model:  ARIMA(1,1,1)(0,0,1)[12]
# Total fit time: 30.345 seconds
# Best SARIMA parameters for Oil_Close: (1, 1, 1), (0, 0, 1, 12)
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=89576.837, Time=1.07 sec
# Processing column: EUR to USD Exchange Rate
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=27538.184, Time=16.12 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=42072.509, Time=16.73 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=35376.212, Time=16.57 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=89605.334, Time=0.94 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=-28810.313, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=-28821.176, Time=0.18 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=-28818.746, Time=0.69 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=29004.582, Time=6.72 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=89546.032, Time=1.68 sec
#  ARIMA(2,1,0)(2,0,1)[12] intercept   : AIC=50420.693, Time=8.58 sec
#  ARIMA(1,1,1)(2,0,1)[12] intercept   : AIC=inf, Time=7.38 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=13636.287, Time=6.88 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=-28818.656, Time=1.31 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=-28822.703, Time=0.06 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=119194.073, Time=12.51 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=133904.965, Time=0.93 sec
#  ARIMA(0,1,0)(1,0,0)[12] intercept   : AIC=-28819.948, Time=0.62 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=5.81 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=119196.058, Time=0.63 sec
#  ARIMA(0,1,0)(0,0,1)[12] intercept   : AIC=-28819.880, Time=0.31 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=13634.468, Time=1.74 sec
#  ARIMA(0,1,0)(1,0,1)[12] intercept   : AIC=-28817.824, Time=1.13 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=133855.120, Time=1.59 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=-28820.020, Time=0.15 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=-28820.001, Time=0.28 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=133856.980, Time=0.56 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=-28817.174, Time=0.50 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[12]
# Total fit time: 6.231 seconds
# Best SARIMA parameters for EUR to USD Exchange Rate: (0, 1, 0), (0, 0, 0, 12)
# Processing column: btc_close
# Performing stepwise search to minimize aic
#  ARIMA(2,1,3)(0,0,1)[12] intercept   : AIC=88677.241, Time=6.36 sec
#  ARIMA(2,1,0)(1,0,2)[12] intercept   : AIC=50420.719, Time=6.23 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=50424.009, Time=0.10 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=60216.491, Time=3.42 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=60239.587, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=60228.377, Time=0.33 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=60229.661, Time=0.39 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=60240.251, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=119196.481, Time=6.49 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=88819.202, Time=1.79 sec
#  ARIMA(2,1,0)(0,0,2)[12] intercept   : AIC=50419.362, Time=1.56 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=133856.532, Time=6.06 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=36596.209, Time=17.24 sec
#  ARIMA(2,1,0)(2,0,0)[12] intercept   : AIC=50419.123, Time=1.85 sec
#  ARIMA(0,1,0)(2,0,2)[12] intercept   : AIC=29006.910, Time=10.19 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=60229.888, Time=2.67 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=60228.741, Time=2.36 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=4.07 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=50422.585, Time=4.23 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=119196.521, Time=6.46 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=42072.550, Time=17.41 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=88653.705, Time=7.30 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=36594.867, Time=5.83 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=133856.468, Time=2.27 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=50420.954, Time=1.83 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=27633.146, Time=18.74 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=35377.203, Time=18.03 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=50420.066, Time=2.14 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=13636.245, Time=16.11 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=50419.091, Time=1.77 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=13642.596, Time=1.95 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=88646.730, Time=5.67 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=35386.222, Time=6.05 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=50422.046, Time=2.77 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=50420.167, Time=0.76 sec
#
# Best model:  ARIMA(2,1,0)(1,0,1)[12] intercept
# Total fit time: 57.355 seconds
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=13636.387, Time=3.32 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=27554.884, Time=7.35 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=22.15 sec
# Best SARIMA parameters for DJI: (2, 1, 0), (1, 0, 1, 12)
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=42079.015, Time=7.30 sec
#  ARIMA(0,1,3)(0,0,1)[12] intercept   : AIC=13641.686, Time=0.74 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=60216.739, Time=11.96 sec
#  ARIMA(2,1,1)(0,0,1)[12] intercept   : AIC=13641.146, Time=1.36 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=29005.923, Time=15.66 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=inf, Time=11.57 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=133914.899, Time=0.54 sec
#  ARIMA(2,1,1)(0,0,2)[12] intercept   : AIC=35385.314, Time=7.48 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=36596.475, Time=15.91 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=119196.055, Time=17.14 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=inf, Time=4.29 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=42078.865, Time=8.28 sec
#  ARIMA(2,1,3)(0,0,1)[12] intercept   : AIC=inf, Time=6.92 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=13632.409, Time=0.84 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=119194.942, Time=1.98 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=13635.106, Time=0.26 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=60216.513, Time=9.63 sec
#  ARIMA(1,1,2)(1,0,1)[12]             : AIC=13633.098, Time=1.41 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=inf, Time=2.92 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=60237.359, Time=0.59 sec
#  ARIMA(0,1,3)(1,0,0)[12] intercept   : AIC=133979.010, Time=0.77 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=119193.854, Time=2.46 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=27582.513, Time=12.70 sec
#  ARIMA(1,1,2)(0,0,2)[12]             : AIC=13634.289, Time=2.27 sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=88626.872, Time=16.83 sec
#  ARIMA(1,1,2)(1,0,0)[12]             : AIC=13632.469, Time=0.75 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=29006.000, Time=14.72 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=119190.463, Time=5.25 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=60222.610, Time=6.96 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=133818.113, Time=6.33 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=19.54 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=13634.247, Time=5.60 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=119194.197, Time=2.41 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=13639.579, Time=0.25 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=133845.147, Time=1.94 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=13640.192, Time=0.42 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=1.61 sec
#  ARIMA(2,1,2)(0,0,1)[12]             : AIC=13640.598, Time=0.81 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=119194.235, Time=2.64 sec
#  ARIMA(1,1,3)(0,0,1)[12]             : AIC=13634.389, Time=1.51 sec
#  ARIMA(3,1,2)(0,0,2)[12] intercept   : AIC=35374.441, Time=16.97 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=13640.104, Time=0.18 sec
#  ARIMA(0,1,3)(0,0,1)[12]             : AIC=13639.688, Time=0.31 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=13639.148, Time=1.01 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=36598.170, Time=16.78 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=36639.847, Time=0.94 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=60221.177, Time=7.18 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=42078.097, Time=18.29 sec
#  ARIMA(2,1,1)(1,0,0)[12] intercept   : AIC=36639.677, Time=1.45 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=29003.980, Time=11.14 sec
#  ARIMA(3,0,2)(0,0,2)[12] intercept   : AIC=27540.344, Time=15.66 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=35375.334, Time=5.21 sec
#  ARIMA(2,1,3)(0,0,1)[12]             : AIC=inf, Time=3.95 sec
#
# Best model:  ARIMA(1,1,2)(0,0,1)[12]
# Total fit time: 85.967 seconds
# Best SARIMA parameters for CBOE Volatility Index: (1, 1, 2), (0, 0, 1, 12)
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=42074.736, Time=4.00 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=36595.915, Time=5.45 sec
#  ARIMA(2,1,3)(2,0,1)[12] intercept   : AIC=88632.955, Time=18.46 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=42074.610, Time=4.19 sec
#  ARIMA(3,1,2)(2,0,1)[12] intercept   : AIC=119191.902, Time=13.53 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=inf, Time=16.31 sec
#  ARIMA(2,1,3)(1,0,0)[12] intercept   : AIC=36595.960, Time=5.09 sec
#  ARIMA(1,1,3)(2,0,0)[12] intercept   : AIC=89499.093, Time=5.31 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=42083.725, Time=2.92 sec
#  ARIMA(1,1,1)(1,0,0)[12] intercept   : AIC=36639.392, Time=1.51 sec
#  ARIMA(2,1,3)(2,0,0)[12] intercept   : AIC=133820.772, Time=18.74 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=42083.720, Time=1.90 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=36637.368, Time=1.25 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=36636.439, Time=1.38 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=42073.645, Time=2.92 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=29007.875, Time=15.52 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=60211.685, Time=17.89 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=27541.653, Time=15.44 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=5.40 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=89350.258, Time=7.08 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=35376.696, Time=17.43 sec
#  ARIMA(0,1,1)(2,0,2)[12]             : AIC=29005.395, Time=3.66 sec
#
# Best model:  ARIMA(0,1,1)(2,0,2)[12] intercept
# Total fit time: 104.692 seconds
# Best SARIMA parameters for Gold_Close: (0, 1, 1), (2, 0, 2, 12)
#  ARIMA(3,1,3)(1,0,0)[12] intercept   : AIC=36595.189, Time=5.96 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=27658.502, Time=4.26 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=42070.889, Time=6.21 sec
#  ARIMA(2,1,2)(1,0,0)[12]             : AIC=36593.215, Time=2.03 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=119191.894, Time=14.07 sec
#  ARIMA(2,1,2)(0,0,0)[12]             : AIC=36603.068, Time=0.69 sec
#  ARIMA(2,1,3)(0,0,1)[12] intercept   : AIC=133841.672, Time=6.23 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=119192.833, Time=0.59 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=35375.908, Time=5.48 sec
#  ARIMA(1,1,3)(0,0,1)[12] intercept   : AIC=42074.025, Time=4.62 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=inf, Time=16.51 sec
#  ARIMA(2,1,2)(2,0,0)[12]             : AIC=36594.656, Time=5.77 sec
#  ARIMA(1,0,3)(0,0,2)[12] intercept   : AIC=27541.530, Time=8.50 sec
#  ARIMA(1,1,3)(1,0,0)[12] intercept   : AIC=42073.994, Time=3.42 sec
#  ARIMA(3,1,2)(0,0,2)[12] intercept   : AIC=119193.398, Time=7.02 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=60210.688, Time=14.42 sec
#  ARIMA(3,1,1)(0,0,2)[12] intercept   : AIC=35385.785, Time=6.97 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=36594.002, Time=2.64 sec
#  ARIMA(2,1,2)(0,0,1)[12]             : AIC=36593.130, Time=2.25 sec
#  ARIMA(3,1,3)(2,0,0)[12] intercept   : AIC=88622.136, Time=18.88 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=60215.116, Time=6.29 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=119193.482, Time=7.96 sec
#  ARIMA(2,1,2)(0,0,2)[12]             : AIC=36594.664, Time=5.72 sec
#  ARIMA(2,1,3)(2,0,1)[12] intercept   : AIC=inf, Time=15.97 sec
#  ARIMA(3,0,1)(0,0,2)[12] intercept   : AIC=27541.402, Time=12.31 sec
#  ARIMA(3,1,3)(1,0,0)[12] intercept   : AIC=88634.754, Time=5.28 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=60215.356, Time=5.75 sec
#  ARIMA(1,1,3)(2,0,1)[12] intercept   : AIC=42071.339, Time=13.21 sec
#  ARIMA(3,1,3)(1,0,0)[12] intercept   : AIC=133816.340, Time=5.23 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=60215.123, Time=2.04 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=18.25 sec
#  ARIMA(2,1,2)(1,0,2)[12]             : AIC=36596.114, Time=6.41 sec
#  ARIMA(1,1,2)(0,0,1)[12]             : AIC=36637.664, Time=0.51 sec
#  ARIMA(3,1,3)(0,0,0)[12] intercept   : AIC=133817.382, Time=1.92 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=2906.271, Time=1.87 sec
#  ARIMA(2,1,1)(0,0,1)[12]             : AIC=36637.493, Time=0.64 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=2906.207, Time=1.89 sec
#  ARIMA(3,1,2)(0,0,1)[12]             : AIC=36594.467, Time=2.24 sec
#  ARIMA(3,1,3)(0,0,2)[12] intercept   : AIC=35380.324, Time=19.39 sec
#  ARIMA(2,1,3)(0,0,1)[12]             : AIC=36594.407, Time=2.34 sec
#  ARIMA(1,1,1)(0,0,1)[12]             : AIC=36637.163, Time=0.66 sec
#  ARIMA(1,1,3)(0,0,1)[12]             : AIC=36635.210, Time=0.65 sec
#  ARIMA(3,1,1)(0,0,1)[12]             : AIC=36634.316, Time=0.54 sec
#  ARIMA(3,1,2)(2,0,2)[12] intercept   : AIC=119193.915, Time=15.13 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=2894.223, Time=5.30 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=60212.785, Time=10.92 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=119188.905, Time=2.64 sec
#  ARIMA(3,1,3)(0,0,1)[12]             : AIC=36593.883, Time=2.95 sec
#
# Best model:  ARIMA(2,1,2)(0,0,1)[12]
# Total fit time: 130.900 seconds
# Best SARIMA parameters for Shanghai Composite Index: (2, 1, 2), (0, 0, 1, 12)
#  ARIMA(3,0,3)(0,0,2)[12] intercept   : AIC=inf, Time=16.07 sec
#  ARIMA(3,1,1)(0,0,1)[12] intercept   : AIC=119192.609, Time=1.85 sec
#  ARIMA(1,1,3)(1,0,2)[12] intercept   : AIC=42071.398, Time=16.23 sec
#  ARIMA(3,1,1)(1,0,0)[12] intercept   : AIC=119192.644, Time=1.20 sec
#  ARIMA(3,1,3)(2,0,1)[12] intercept   : AIC=88631.291, Time=18.28 sec
#  ARIMA(1,1,3)(0,0,0)[12] intercept   : AIC=42072.572, Time=1.05 sec
#  ARIMA(2,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=6.74 sec
#  ARIMA(2,0,2)(0,0,2)[12]             : AIC=27608.149, Time=3.37 sec
#
# Best model:  ARIMA(2,0,2)(0,0,2)[12] intercept
# Total fit time: 145.804 seconds
# Best SARIMA parameters for google_trends_bitcoin: (2, 0, 2), (0, 0, 2, 12)
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=2905.582, Time=0.72 sec
#  ARIMA(3,1,3)(2,0,0)[12] intercept   : AIC=133818.232, Time=16.63 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=2905.739, Time=2.35 sec
#  ARIMA(3,1,1)(1,0,1)[12] intercept   : AIC=2905.591, Time=2.11 sec
#  ARIMA(2,1,3)(0,0,2)[12] intercept   : AIC=35377.397, Time=15.79 sec
#  ARIMA(3,1,3)(1,0,1)[12] intercept   : AIC=88653.019, Time=5.97 sec
#  ARIMA(3,1,1)(2,0,1)[12] intercept   : AIC=119190.312, Time=7.49 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=60214.525, Time=12.55 sec
#  ARIMA(3,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=6.65 sec
#  ARIMA(3,1,2)(0,0,2)[12]             : AIC=35377.027, Time=5.27 sec
#
# Best model:  ARIMA(3,1,2)(0,0,2)[12] intercept
# Total fit time: 156.217 seconds
# Best SARIMA parameters for GSPC: (3, 1, 2), (0, 0, 2, 12)
#  ARIMA(1,1,3)(0,0,2)[12] intercept   : AIC=42073.337, Time=11.65 sec
#  ARIMA(3,1,3)(1,0,1)[12] intercept   : AIC=inf, Time=6.83 sec
#  ARIMA(3,1,1)(1,0,2)[12] intercept   : AIC=119190.304, Time=7.44 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=119191.210, Time=0.21 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=inf, Time=2.35 sec
#
# Best model:  ARIMA(2,1,2)(1,0,1)[12] intercept
# Total fit time: 143.934 seconds
# Best SARIMA parameters for USD Index (DXY): (2, 1, 2), (1, 0, 1, 12)
#  ARIMA(3,1,3)(0,0,1)[12] intercept   : AIC=133817.022, Time=5.53 sec
#  ARIMA(3,1,2)(2,0,0)[12] intercept   : AIC=89478.603, Time=9.69 sec
#  ARIMA(3,1,1)(0,0,2)[12] intercept   : AIC=119191.790, Time=5.54 sec
#  ARIMA(1,1,3)(2,0,0)[12] intercept   : AIC=42073.145, Time=8.72 sec
#  ARIMA(1,1,3)(2,0,2)[12] intercept   : AIC=60212.598, Time=13.61 sec
#  ARIMA(3,1,1)(2,0,0)[12] intercept   : AIC=119191.872, Time=2.73 sec
#  ARIMA(0,1,1)(2,0,2)[12] intercept   : AIC=60215.726, Time=5.73 sec
#  ARIMA(3,1,3)(2,0,0)[12]             : AIC=88626.602, Time=13.91 sec
#
# Best model:  ARIMA(3,1,3)(2,0,0)[12] intercept
# Total fit time: 174.657 seconds
# Best SARIMA parameters for active_addresses_blockchain: (3, 1, 3), (2, 0, 0, 12)
#  ARIMA(3,1,3)(2,0,1)[12] intercept   : AIC=inf, Time=15.13 sec
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=119192.517, Time=9.73 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=133857.376, Time=2.33 sec
#  ARIMA(3,1,0)(1,0,1)[12] intercept   : AIC=119190.833, Time=1.35 sec
#  ARIMA(1,1,3)(2,0,2)[12] intercept   : AIC=42072.869, Time=13.49 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=119249.084, Time=1.06 sec
#  ARIMA(3,1,1)(1,0,1)[12]             : AIC=119187.107, Time=1.82 sec
#  ARIMA(3,1,3)(1,0,0)[12]             : AIC=133816.510, Time=4.12 sec
#
# Best model:  ARIMA(3,1,3)(1,0,0)[12] intercept
# Total fit time: 181.849 seconds
# Best SARIMA parameters for hash_rate_blockchain: (3, 1, 3), (1, 0, 0, 12)
#  ARIMA(3,1,1)(0,0,1)[12]             : AIC=119190.822, Time=0.84 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=42074.634, Time=3.92 sec
#  ARIMA(3,1,1)(1,0,0)[12]             : AIC=119190.855, Time=0.92 sec
#  ARIMA(0,1,3)(2,0,2)[12] intercept   : AIC=60214.793, Time=12.09 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=42072.766, Time=1.91 sec
#  ARIMA(1,1,3)(1,0,1)[12]             : AIC=42074.988, Time=1.39 sec
#
# Best model:  ARIMA(1,1,3)(1,0,1)[12] intercept
# Total fit time: 186.264 seconds
# Best SARIMA parameters for NYSE FANG+: (1, 1, 3), (1, 0, 1, 12)
#  ARIMA(3,1,1)(2,0,1)[12]             : AIC=119188.520, Time=6.29 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=60210.492, Time=7.75 sec
#  ARIMA(3,1,1)(1,0,2)[12]             : AIC=119188.513, Time=6.33 sec
#  ARIMA(3,1,1)(0,0,0)[12]             : AIC=119189.426, Time=0.34 sec
#  ARIMA(2,1,1)(1,0,2)[12] intercept   : AIC=60215.052, Time=5.76 sec
#  ARIMA(3,1,1)(0,0,2)[12]             : AIC=119190.009, Time=4.58 sec
#  ARIMA(3,1,1)(2,0,0)[12]             : AIC=119190.093, Time=2.32 sec
#  ARIMA(2,1,1)(2,0,1)[12] intercept   : AIC=60215.288, Time=5.80 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=60215.047, Time=1.57 sec
#  ARIMA(3,1,1)(2,0,2)[12]             : AIC=119190.682, Time=8.21 sec
#  ARIMA(2,1,1)(1,0,1)[12]             : AIC=119192.088, Time=1.50 sec
#  ARIMA(2,1,0)(2,0,2)[12] intercept   : AIC=60212.502, Time=8.33 sec
#  ARIMA(3,1,0)(1,0,1)[12]             : AIC=119188.999, Time=1.21 sec
#  ARIMA(3,1,2)(1,0,1)[12]             : AIC=119188.672, Time=2.72 sec
#  ARIMA(2,1,0)(1,0,1)[12]             : AIC=119247.216, Time=0.91 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=119190.763, Time=2.58 sec
#
# Best model:  ARIMA(3,1,1)(1,0,1)[12]
# Total fit time: 220.361 seconds
# Best SARIMA parameters for miner_revenue_blockchain: (3, 1, 1), (1, 0, 1, 12)
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=60212.352, Time=10.44 sec
#  ARIMA(1,1,0)(2,0,2)[12] intercept   : AIC=60215.485, Time=5.63 sec
#  ARIMA(3,1,0)(2,0,2)[12] intercept   : AIC=60214.386, Time=8.06 sec
#  ARIMA(3,1,2)(2,0,2)[12] intercept   : AIC=60214.259, Time=11.77 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=60210.853, Time=5.51 sec
#
# Best model:  ARIMA(2,1,1)(2,0,2)[12] intercept
# Total fit time: 217.497 seconds
# Best SARIMA parameters for btc_close: (2, 1, 1), (2, 0, 2, 12)
#
# SARIMA parameters for each column:
# Column: google_trends_bitcoin
# Order: (2, 0, 2)
# Seasonal Order: (0, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 0, 2), scoring_args={}, seasonal_order=(0, 0, 2, 12),
#       suppress_warnings=True)>
# ------
# Column: active_addresses_blockchain
# Order: (3, 1, 3)
# Seasonal Order: (2, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(3, 1, 3), scoring_args={}, seasonal_order=(2, 0, 0, 12),
#       suppress_warnings=True)>
# ------
# Column: hash_rate_blockchain
# Order: (3, 1, 3)
# Seasonal Order: (1, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(3, 1, 3), scoring_args={}, seasonal_order=(1, 0, 0, 12),
#       suppress_warnings=True)>
# ------
# Column: miner_revenue_blockchain
# Order: (3, 1, 1)
# Seasonal Order: (1, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: Gold_Close
# Order: (0, 1, 1)
# Seasonal Order: (2, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True)>
# ------
# Column: Oil_Close
# Order: (1, 1, 1)
# Seasonal Order: (0, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(1, 1, 1), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: DJI
# Order: (2, 1, 0)
# Seasonal Order: (1, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 1, 0), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True)>
# ------
# Column: GSPC
# Order: (3, 1, 2)
# Seasonal Order: (0, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(3, 1, 2), scoring_args={}, seasonal_order=(0, 0, 2, 12),
#       suppress_warnings=True)>
# ------
# Column: IXIC
# Order: (0, 1, 1)
# Seasonal Order: (0, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(0, 1, 1), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)>
# ------
# Column: NYSE FANG+
# Order: (1, 1, 3)
# Seasonal Order: (1, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(1, 1, 3), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True)>
# ------
# Column: ARK Innovation ETF
# Order: (0, 1, 0)
# Seasonal Order: (0, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: CBOE Volatility Index
# Order: (1, 1, 2)
# Seasonal Order: (0, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(1, 1, 2), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: iShares MSCI Emerging Markets ETF
# Order: (1, 1, 0)
# Seasonal Order: (0, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: Shanghai Composite Index
# Order: (2, 1, 2)
# Seasonal Order: (0, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 1, 2), scoring_args={}, seasonal_order=(0, 0, 1, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: USD Index (DXY)
# Order: (2, 1, 2)
# Seasonal Order: (1, 0, 1, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 12),
#       suppress_warnings=True)>
# ------
# Column: EUR to USD Exchange Rate
# Order: (0, 1, 0)
# Seasonal Order: (0, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: btc_close
# Order: (2, 1, 1)
# Seasonal Order: (2, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 1, 1), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True)>
# ------

# %%
btc_price = pd.read_csv("../data/raw/historical_data.csv", parse_dates=["Date"], index_col="Date")

high_low_vol_col = ['High', 'Low', 'Volume']

# Function to fit auto_arima and return the model
def fit_auto_arima(series, seasonal_period=12):
    model = auto_arima(
        series,
        seasonal=True,
        m=seasonal_period,  # Seasonality (e.g., 12 for monthly data)
        max_p=3, max_d=1, max_q=3,  # Non-seasonal order limits
        max_P=2, max_D=1, max_Q=2,  # Seasonal order limits
        trace=True,  # Print progress
        error_action='ignore',  # Ignore fitting errors
        suppress_warnings=True
    )
    return model

# Function to process each column in parallel
def process_column(column_name, series, seasonal_period=12):
    print(f"Processing column: {column_name}")
    model = fit_auto_arima(series, seasonal_period)
    print(f"Best SARIMA parameters for {column_name}: {model.order}, {model.seasonal_order}")
    return {
        'column': column_name,
        'order': model.order,
        'seasonal_order': model.seasonal_order,
        'model': model
    }

# Seasonal period (set based on your data's seasonality)
seasonal_period = 12  # Example: 12 for monthly data with yearly seasonality

# Process all columns in parallel
results = Parallel(n_jobs=-1)(
    delayed(process_column)(column, btc_price[column], seasonal_period)
    for column in high_low_vol_col
)

# Store results in a dictionary
sarima_params2 = {result['column']: result for result in results}

# Print the results
print("\nSARIMA parameters for each column:")
for column, result in sarima_params2.items():
    print(f"Column: {column}")
    print(f"Order: {result['order']}")
    print(f"Seasonal Order: {result['seasonal_order']}")
    print(f"Model AIC: {result['model'].aic}")
    print("------")
# Out:
# Processing column: Low
# Processing column: VolumeProcessing column: High
#
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=177649.548, Time=1.26 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=178860.476, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=178366.563, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=177773.305, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=178858.489, Time=0.02 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=177650.333, Time=0.75 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=60120.907, Time=3.21 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=59128.408, Time=3.22 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=60161.884, Time=0.02 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=59198.627, Time=0.02 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=177652.357, Time=0.73 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=60158.554, Time=0.17 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=59128.165, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=60158.557, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=59130.503, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=60162.583, Time=0.01 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=59200.206, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=59126.346, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=59128.174, Time=0.20 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=59130.232, Time=0.23 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=59128.322, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=59128.328, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=59128.603, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=59130.300, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=59127.030, Time=0.02 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12] intercept
# Total fit time: 4.476 seconds
# Best SARIMA parameters for High: (1, 1, 0), (0, 0, 0, 12)
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=60130.362, Time=3.90 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=177629.677, Time=7.18 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=60132.939, Time=4.15 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=177632.279, Time=5.21 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=60130.845, Time=14.25 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=12.52 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=177627.066, Time=7.14 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=177636.770, Time=2.47 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=60134.391, Time=12.81 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=60128.519, Time=0.94 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=177626.043, Time=5.15 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=177634.351, Time=2.74 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=177647.282, Time=1.35 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=60131.402, Time=13.59 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=11.09 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=177648.208, Time=0.82 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=177628.348, Time=3.75 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=60130.071, Time=13.33 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=177624.628, Time=4.04 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=177632.572, Time=1.53 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=177645.541, Time=0.90 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=inf, Time=8.38 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=177646.623, Time=0.41 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=60115.776, Time=12.22 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=177626.574, Time=2.36 sec
#  ARIMA(0,1,1)(1,0,2)[12] intercept   : AIC=177743.414, Time=2.74 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=60147.374, Time=7.14 sec
#  ARIMA(0,1,3)(1,0,2)[12] intercept   : AIC=177628.042, Time=5.00 sec
#  ARIMA(2,1,1)(2,0,2)[12] intercept   : AIC=60146.928, Time=5.68 sec
#  ARIMA(1,1,1)(1,0,2)[12] intercept   : AIC=177640.494, Time=4.68 sec
#  ARIMA(3,1,2)(2,0,2)[12] intercept   : AIC=60121.229, Time=13.15 sec
#  ARIMA(1,1,3)(1,0,2)[12] intercept   : AIC=177628.143, Time=12.53 sec
#  ARIMA(0,1,2)(1,0,2)[12]             : AIC=177622.703, Time=3.99 sec
#  ARIMA(0,1,2)(0,0,2)[12]             : AIC=177627.891, Time=1.47 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=177635.959, Time=0.86 sec
#  ARIMA(2,1,3)(2,0,2)[12] intercept   : AIC=60118.744, Time=15.86 sec
#  ARIMA(0,1,2)(2,0,2)[12]             : AIC=inf, Time=9.20 sec
#  ARIMA(0,1,2)(0,0,1)[12]             : AIC=177642.446, Time=0.38 sec
#  ARIMA(0,1,2)(2,0,1)[12]             : AIC=177624.234, Time=2.59 sec
#  ARIMA(0,1,1)(1,0,2)[12]             : AIC=177741.799, Time=2.66 sec
#  ARIMA(1,1,1)(2,0,2)[12] intercept   : AIC=60146.339, Time=10.57 sec
#  ARIMA(1,1,2)(1,0,2)[12]             : AIC=177623.969, Time=5.52 sec
#  ARIMA(0,1,3)(1,0,2)[12]             : AIC=177625.459, Time=5.09 sec
#  ARIMA(1,1,1)(1,0,2)[12]             : AIC=177638.775, Time=4.42 sec
#  ARIMA(1,1,3)(2,0,2)[12] intercept   : AIC=60141.062, Time=11.29 sec
#  ARIMA(1,1,3)(1,0,2)[12]             : AIC=177627.363, Time=5.55 sec
#
# Best model:  ARIMA(0,1,2)(1,0,2)[12]
# Total fit time: 147.143 seconds
# Best SARIMA parameters for Volume: (0, 1, 2), (1, 0, 2, 12)
#  ARIMA(3,1,1)(2,0,2)[12] intercept   : AIC=60142.659, Time=11.07 sec
#  ARIMA(3,1,3)(2,0,2)[12] intercept   : AIC=60127.357, Time=17.37 sec
#  ARIMA(2,1,2)(2,0,2)[12]             : AIC=60115.137, Time=9.37 sec
#  ARIMA(2,1,2)(1,0,2)[12]             : AIC=60129.246, Time=10.19 sec
#  ARIMA(2,1,2)(2,0,1)[12]             : AIC=60133.429, Time=6.79 sec
#  ARIMA(2,1,2)(1,0,1)[12]             : AIC=60119.857, Time=2.64 sec
#  ARIMA(1,1,2)(2,0,2)[12]             : AIC=60146.243, Time=8.16 sec
#  ARIMA(2,1,1)(2,0,2)[12]             : AIC=60148.065, Time=5.94 sec
#  ARIMA(3,1,2)(2,0,2)[12]             : AIC=60116.989, Time=11.23 sec
#  ARIMA(2,1,3)(2,0,2)[12]             : AIC=60118.612, Time=11.28 sec
#  ARIMA(1,1,1)(2,0,2)[12]             : AIC=60145.640, Time=5.37 sec
#  ARIMA(1,1,3)(2,0,2)[12]             : AIC=60140.161, Time=7.38 sec
#  ARIMA(3,1,1)(2,0,2)[12]             : AIC=60141.728, Time=7.12 sec
#  ARIMA(3,1,3)(2,0,2)[12]             : AIC=60127.744, Time=7.95 sec
#
# Best model:  ARIMA(2,1,2)(2,0,2)[12]
# Total fit time: 264.453 seconds
# Best SARIMA parameters for Low: (2, 1, 2), (2, 0, 2, 12)
#
# SARIMA parameters for each column:
# Column: High
# Order: (1, 1, 0)
# Seasonal Order: (0, 0, 0, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(1, 1, 0), scoring_args={}, seasonal_order=(0, 0, 0, 12),
#       suppress_warnings=True)>
# ------
# Column: Low
# Order: (2, 1, 2)
# Seasonal Order: (2, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(2, 1, 2), scoring_args={}, seasonal_order=(2, 0, 2, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------
# Column: Volume
# Order: (0, 1, 2)
# Seasonal Order: (1, 0, 2, 12)
# Model AIC: <bound method ARIMA.aic of ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(1, 0, 2, 12),
#       suppress_warnings=True, with_intercept=False)>
# ------

# %%
# Extract only serializable data
serializable_params = {
    feature: {
        'column': params['column'],
        'order': params['order'],
        'seasonal_order': params['seasonal_order']
    }
    for feature, params in sarima_params.items()
}
# Out:
# Serializable SARIMA parameters exported to sarima_params.json

# %%
# Extract only serializable data from new_sarima_params
new_serializable_params = {
    feature: {
        'column': params['column'],
        'order': params['order'],
        'seasonal_order': params['seasonal_order']
    }
    for feature, params in sarima_params2.items()
}

# Append new_serializable_params to serializable_params
serializable_params.update(new_serializable_params)


# Save to JSON
with open('../results/metrics/sarima_params.json', 'w') as f:
    json.dump(serializable_params, f, indent=4)
print("Serializable SARIMA parameters exported to sarima_params.json")
# Out:
# Serializable SARIMA parameters exported to sarima_params.json
