# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/final/dataset.csv", parse_dates=["Date"], index_col="Date")

# %% [markdown]
# # Indicators Tree
#
# - **Sentiment Indicators**
#   - google_trends_bitcoin
#
# - **Blockchain Metrics**
#   - active_addresses_blockchain
#   - hash_rate_blockchain
#   - miner_revenue_blockchain
#
# - **Technical Indicators**
#   - btc_sma_14 (14-Day Simple Moving Average)
#   - btc_ema_14 (14-Day Exponential Moving Average)
#   - btc_rsi_14 (14-Day Relative Strength Index)
#   - btc_macd (Moving Average Convergence Divergence)
#   - btc_macd_signal (9-Day EMA of MACD)
#   - btc_macd_diff (Difference between btc_macd and btc_macd_signal)
#   - Bollinger Bands
#     - btc_bb_high (Upper Band)
#     - btc_bb_low (Lower Band)
#     - btc_bb_mid (Mid Band - 20-Day SMA)
#   - btc_bb_width (Width of Bollinger Bands)
#   - btc_atr_14 (14-Day Average True Range)
#
# - **Market Metrics**
#   - btc_trading_volume
#   - btc_volatility_index
#
# - **Macro and Cross-Market Metrics**
#   - Gold_Close
#   - Oil_Close
#   - DJI (Dow Jones Industrial Average)
#   - GSPC (S&P 500)
#   - IXIC (NASDAQ Composite)
#   - NYSE FANG+ (High-Growth Tech Stocks Index)
#   - ARK Innovation ETF (Disruptive Tech ETF)
#   - CBOE Volatility Index (VIX)
#   - iShares MSCI Emerging Markets ETF
#   - Shanghai Composite Index
#   - USD Index (DXY)
#   - EUR to USD Exchange Rate
#
# - **Bitcoin-Specific Outcome Variable**
#   - btc_close (Primary Target Variable)

# %% [markdown]
# Here’s a detailed explanation of the given features, tailored to Bitcoin analysis, categorized into **Sentiment Indicators**, **Blockchain Metrics**, **Technical Indicators**, and **Macro/Market Metrics**:
#
# **Sentiment Indicators**
#
# 1.	google_trends_bitcoin
#
# Tracks the popularity of Bitcoin-related search terms over time. Higher values often indicate heightened public interest, which can lead to increased market activity or speculative price changes.
#
# **Blockchain Metrics**
#
# 2.	active_addresses_blockchain
#
# Number of unique Bitcoin addresses participating in transactions. This reflects the level of activity and adoption on the Bitcoin network. Higher values may suggest increased usage or network engagement.
#
# 3.	hash_rate_blockchain
#
# Measures the total computational power used by miners on the Bitcoin network. A higher hash rate indicates greater network security and miner confidence. Sharp drops can suggest miner capitulation, potentially signaling bearish trends.
#
# 4.	miner_revenue_blockchain
#
# Total earnings by Bitcoin miners (block rewards + transaction fees). It reflects the profitability of mining and can influence miner behavior, such as selling or holding mined BTC.
#
# **Technical Indicators**
#
# 5.	btc_sma_14 **(14-Day Simple Moving Average)**
#
# A lagging indicator that shows the average Bitcoin closing price over 14 days. It smooths out price data to identify overall trends and support/resistance levels.
#
# 6.	btc_ema_14 **(14-Day Exponential Moving Average)**
#
# Similar to SMA but gives more weight to recent prices. EMA is often used in fast-moving markets like Bitcoin to detect short-term trends.
#
# 7.	btc_rsi_14 **(14-Day Relative Strength Index)**
#
# Oscillates between 0 and 100, measuring the speed and change of price movements. RSI > 70 indicates overbought conditions (potential reversal); RSI < 30 suggests oversold conditions (potential recovery).
#
# 8.	btc_macd **(Moving Average Convergence Divergence)**
#
# Represents the difference between a short-term EMA (usually 12 days) and a longer-term EMA (26 days). Positive values indicate bullish momentum.
#
# 9.	btc_macd_signal
#
# The 9-day EMA of the MACD. Often used as a trigger line for buy/sell signals when crossed by the MACD.
#
# 10.	btc_macd_diff
#
# The difference between btc_macd and btc_macd_signal. Positive values suggest upward momentum, while negative values suggest downward momentum.
#
# 11.	btc_bb_high**,** btc_bb_low**,** btc_bb_mid **(Bollinger Bands)**
#
# •	**High**: Upper boundary indicating overbought conditions.
#
# •	**Low**: Lower boundary indicating oversold conditions.
#
# •	**Mid**: The SMA used to calculate the bands (usually 20 days). These bands measure price volatility.
#
# 12.	btc_bb_width
#
# The distance between the upper and lower Bollinger Bands. Expanding width indicates increasing volatility, while contracting width suggests decreasing volatility.
#
# 13.	btc_atr_14 **(14-Day Average True Range)**
#
# Measures Bitcoin’s volatility by calculating the average range between daily high and low prices over 14 days. Higher ATR suggests higher market volatility.
#
# **Market Metrics**
#
# 14.	btc_trading_volume
#
# Represents the total number of Bitcoin traded during a given period. High volume during price moves can confirm the trend; low volume may indicate potential reversals.
#
# 15.	btc_volatility_index
#
# Quantifies Bitcoin’s historical price volatility. Higher values suggest more unpredictable price movements.
#
# **Macro and Cross-Market Metrics**
#
# 16.	Gold_Close
#
# Closing price of gold. Bitcoin and gold are often considered “safe-haven” assets, with their prices sometimes moving inversely to traditional markets.
#
# 17.	Oil_Close
#
# Closing price of crude oil. While not directly related to Bitcoin, it reflects macroeconomic conditions that can influence overall market sentiment.
#
# 18.	DJI **(Dow Jones Industrial Average)**
#
# Tracks 30 large U.S. companies. A barometer for traditional market performance; Bitcoin sometimes reacts inversely during risk-off periods.
#
# 19.	GSPC **(S&P 500)**
#
# Index of 500 large U.S. companies. Like the DJI, its performance can influence Bitcoin through risk sentiment.
#
# 20.	IXIC **(NASDAQ Composite)**
#
# Heavily tech-focused index. Bitcoin’s correlation with tech stocks can make this a key indicator for market sentiment.
#
# 21.	NYSE FANG+
#
# Tracks high-growth tech stocks like Facebook, Amazon, Netflix, and Google. A proxy for speculative sentiment, which can influence Bitcoin prices.
#
# 22.	ARK Innovation ETF
#
# Tracks disruptive tech companies. A popular ETF among risk-tolerant investors, its performance can correlate with Bitcoin’s speculative appeal.
#
# 23.	CBOE Volatility Index **(VIX)**
#
# Measures expected stock market volatility. High VIX values indicate fear in the market, which can drive investors to or away from Bitcoin depending on sentiment.
#
# 24.	iShares MSCI Emerging Markets ETF
#
# Tracks equities in emerging markets. A downturn in emerging markets can drive capital into Bitcoin as an alternative investment.
#
# 25.	Shanghai Composite Index
#
# Tracks Chinese stock performance. Significant because of China’s historical influence on Bitcoin mining and trading.
#
# 26.	USD Index (DXY)
#
# Measures the U.S. dollar’s strength against other major currencies. A stronger dollar often pressures Bitcoin downward, while a weaker dollar supports it.
#
# 27.	EUR to USD Exchange Rate
#
# Reflects Euro-to-Dollar conversion. Can indirectly impact Bitcoin through currency strength dynamics and international investment flows.
#
# **Bitcoin-Specific Outcome Variable**
#
# 28.	btc_close
#
# Bitcoin’s closing price for a given period (e.g., daily, weekly). Used as the primary dependent variable for prediction models. All other features serve as explanatory variables to understand or forecast this value.
#
# **Analysis Insight**
#
# These features span multiple domains—sentiment, blockchain, technical, and macro—providing a holistic view of factors affecting Bitcoin prices. Each contributes uniquely to analyzing or predicting Bitcoin trends, allowing for a robust quantitative and qualitative evaluation.

# %%
# df.info()
# df.isnull().sum()
# df.describe()

# %%
# Date range
print(df.index.min())
print(df.index.max())
# Out:
# 2014-11-16 00:00:00+00:00
# 2024-11-16 00:00:00+00:00

# %%
import plotly.graph_objects as go

fig = go.Figure()

# Add the main trace for BTC close price
fig.add_trace(go.Scatter(
    x=df.index, 
    y=df["btc_close"], 
    mode='lines', 
    name='BTC Close Price',
    line=dict(width=2, color='cyan'),
    hoverinfo='x+y',
))

# Add a moving average for better trend visualization (optional, if applicable)
fig.add_trace(go.Scatter(
    x=df.index, 
    y=df["btc_close"].rolling(window=14).mean(), 
    mode='lines', 
    name='14-Day SMA',
    line=dict(width=1.5, dash='dash', color='orange'),
    hoverinfo='x+y',
))

# Customize layout for better interactivity and aesthetics
fig.update_layout(
    title=dict(
        text='Bitcoin Close Price Over Time',
        font=dict(size=20, color='white'),
        x=0.5,
        xanchor='center'
    ),
    xaxis=dict(
        title='Date',
        titlefont=dict(size=16, color='white'),
        showgrid=True,
        gridcolor='gray',
        showline=True,
        linecolor='white',
        rangeselector=dict(
            buttons=[
                dict(count=7, label='1w', step='day', stepmode='backward'),
                dict(count=1, label='1m', step='month', stepmode='backward'),
                dict(count=3, label='3m', step='month', stepmode='backward'),
                dict(count=1, label='YTD', step='year', stepmode='todate'),
                dict(step='all', label='All')
            ]
        ),
        rangeslider=dict(visible=True),
        type='date'
    ),
    yaxis=dict(
        title='BTC Close Price',
        titlefont=dict(size=16, color='white'),
        showgrid=True,
        gridcolor='gray',
        showline=True,
        linecolor='white'
    ),
    template='plotly_dark',
    hovermode='x unified',
    legend=dict(
        bgcolor='rgba(0,0,0,0)',
        font=dict(size=12, color='white')
    ),
    margin=dict(l=50, r=50, t=80, b=50)
)

# Safely extract the indices of max and min values
max_idx = df["btc_close"].idxmax()
min_idx = df["btc_close"].idxmin()

fig.add_annotation(
    x=max_idx,  # Directly use the DatetimeIndex value
    y=df["btc_close"].max(),
    text='Highest Price',
    showarrow=True,
    arrowhead=2,
    ax=-50,
    ay=-30,
    font=dict(size=12, color='white'),
    bgcolor='rgba(255, 0, 0, 0.6)'
)

fig.add_annotation(
    x=min_idx,  # Directly use the DatetimeIndex value
    y=df["btc_close"].min(),
    text='Lowest Price',
    showarrow=True,
    arrowhead=2,
    ax=50,
    ay=30,
    font=dict(size=12, color='white'),
    bgcolor='rgba(0, 255, 0, 0.6)'
)

fig.show()

# %%
# Analyzing closing price per month 2023

y_2015 = df.loc[(df.index >= '2023-01-01')
                     & (df.index < '2023-12-31')]

y_2015 = y_2015['btc_close']

monthwise = y_2015.groupby(y_2015.index.month).mean()
order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
monthwise.index = order
monthwise.plot(kind='bar', figsize=(10, 6), color='skyblue')
# Out:
# <Axes: >

# %%
# # Group features based on their categories
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Group features by their value ranges
# group1 = [
#     'google_trends_bitcoin'
# ]

# group2 = [
#     'active_addresses_blockchain', 'hash_rate_blockchain', 'miner_revenue_blockchain'
# ]

# group3 = [
#     'btc_sma_14','btc_ema_14','btc_rsi_14','btc_macd','btc_macd_signal','btc_macd_diff','btc_bb_high','btc_bb_low','btc_bb_mid','btc_bb_width','btc_atr_14'
# ]

# group4 = [
#     'btc_trading_volume'
# ]

# group5 = [
#     'btc_volatility_index'
# ]

# group6 = [
#     'Gold_Close','Oil_Close','DJI','GSPC','IXIC','NYSE FANG+'
# ]

# group7 = [
#     'ARK Innovation ETF','CBOE Volatility Index'
# ]

# group8 = [
#     'iShares MSCI Emerging Markets ETF','Shanghai Composite Index'
# ]

# group9 = [
#     'USD Index (DXY)','EUR to USD Exchange Rate'
# ]

# # Plot boxplots for each group
# groups = {
#     "Google Trends": group1,
#     "Bitcoin Blockchain Metrics": group2,
#     "Bitcoin Technical Indicators": group3,
#     "Bitcoin Market Metrics": group4,
#     "Bitcoin Market Metrics": group5,
#     "External Market Data": group6,
#     "External Market Data": group7,
#     "External Market Data": group8,
#     "Macroeconomic Indicators": group9
# }

# for group_name, features in groups.items():
#     plt.figure(figsize=(12, 6))
#     sns.boxplot(data=df[features], orient="h")
#     plt.title(f"Boxplot of {group_name}")
#     plt.show()

# %% [markdown]
# x label oncclude each other
# density plot don't look good

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the bitcoin close price
decomposition = seasonal_decompose(df['btc_close'], model='additive', period=365)

# Plot decomposition
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(df["btc_close"], label="Original", color="blue")
plt.legend(loc="best")

plt.subplot(4, 1, 2)
plt.plot(decomposition.trend, label="Trend", color="red")
plt.legend(loc="best")

plt.subplot(4, 1, 3)
plt.plot(decomposition.seasonal, label="Seasonality", color="green")
plt.legend(loc="best")

plt.subplot(4, 1, 4)
plt.plot(decomposition.resid, label="Residuals", color="purple")
plt.legend(loc="best")

plt.tight_layout()
plt.show()

# %%
gold_oil = pd.read_csv("../data/processed/gold_oil_prices.csv", parse_dates=["Date"], index_col="Date")
macro = pd.read_csv("../data/processed/macro_financial_factors.csv", parse_dates=["Date"], index_col="Date")
# Out:
# /var/folders/pf/4hxrldrx2g7g5x19dwlvk36w0000gn/T/ipykernel_19871/175625541.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
def get_stats_for_column(df, column_name):
    """Calculate descriptive statistics for a given column and return as a dict."""
    stats = df[column_name].describe()
    stats_dict = {
        'Mean': stats['mean'],
        'Median': df[column_name].median(),
        'Std Dev': stats['std'],
        'Min': stats['min'],
        'Max': stats['max'],
        'Skewness': df[column_name].skew(),
        'Kurtosis': df[column_name].kurtosis(),
        '25th': stats['25%'],
        '50th': stats['50%'],
        '75th': stats['75%']
    }
    return pd.Series(stats_dict)

# Create empty list to store statistics
all_stats = []

# Bitcoin statistics
all_stats.append(get_stats_for_column(df, 'btc_close'))

# Gold and Oil statistics
for column in gold_oil.columns:
    all_stats.append(get_stats_for_column(gold_oil, column))

# Macro financial factors statistics
for column in macro.columns:
    all_stats.append(get_stats_for_column(macro, column))

# Create DataFrame with all statistics
stats_df = pd.DataFrame(all_stats, index=['Bitcoin'] + list(gold_oil.columns) + list(macro.columns))

# Format the display
pd.options.display.float_format = '{:,.2f}'.format
stats_df
# Out:
#                                        Mean    Median   Std Dev       Min  \
# Bitcoin                           18,945.09  9,389.83 20,560.91    178.10
# Gold                               1,584.98  1,503.85    377.83  1,050.80
# Oil                                   61.96     59.62     18.09    -37.63
# DJI                               27,375.56 26,499.13  7,163.33 15,660.18
# GSPC                               3,307.48  2,974.48  1,052.81  1,829.08
# IXIC                               9,670.54  8,230.67  4,013.82  4,266.84
# NYSE FANG+                         4,269.79  2,902.86  2,955.56    889.14
# ARK Innovation ETF                    48.87     42.87     30.27     14.78
# CBOE Volatility Index                 18.17     16.27      7.19      9.14
# iShares MSCI Emerging Markets ETF     41.91     41.17      5.55     28.25
# Shanghai Composite Index           3,185.97  3,157.87    339.17  2,451.17
# USD Index (DXY)                       97.85     97.16      4.90     87.53
# ...

# %% [markdown]
# 1. raw data: big picture
# 2. trend: smooth version -> overall long-term trend
# 3. seasonal component: repeating short-term patterns
# 4. residuals: random noise after removing trend & seasonality (what we can't explain). If lack clear pattern, decomposition is successful.

# %%
# Apply first-order differencing
df['btc_close_diff'] = df['btc_close'].diff()

# Drop NaN values introduced by differencing
df = df.dropna(subset=['btc_close_diff'])

# Check the result
df[['btc_close', 'btc_close_diff']].head()
# Out:
#                             btc_close  btc_close_diff
# Date
# 2014-11-17 00:00:00+00:00  387.407990       -0.473999
# 2014-11-18 00:00:00+00:00  375.197998      -12.209991
# 2014-11-19 00:00:00+00:00  380.554993        5.356995
# 2014-11-20 00:00:00+00:00  357.839996      -22.714996
# 2014-11-21 00:00:00+00:00  350.847992       -6.992004

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Perform ADF test before differencing
adf_before = adfuller(df['btc_close'])
adf_after = adfuller(df['btc_close'].diff().dropna())

# Create a DataFrame to compare results
adf_comparison = pd.DataFrame({
    "Metric": ["ADF Statistic", "p-value", "1% Critical Value", "5% Critical Value", "10% Critical Value"],
    "Before Differencing": [adf_before[0], adf_before[1], adf_before[4]["1%"], adf_before[4]["5%"], adf_before[4]["10%"]],
    "After Differencing": [adf_after[0], adf_after[1], adf_after[4]["1%"], adf_after[4]["5%"], adf_after[4]["10%"]]
})
adf_comparison.set_index("Metric", inplace=True)

with pd.option_context('display.float_format', None): 
    print(adf_comparison)
# Out:
#                     Before Differencing  After Differencing
# Metric
# ADF Statistic                  0.293458       -8.360576e+00
# p-value                        0.977042        2.830894e-13
# 1% Critical Value             -3.432156       -3.432157e+00
# 5% Critical Value             -2.862338       -2.862338e+00
# 10% Critical Value            -2.567195       -2.567195e+00

# %% [markdown]
# adf stat not more negative than any of the critial values -> less stationary
# p-value >= 0.05 -> non-stationary
# - critical values:
#   - 1% (-3.4321)
#   - 5% (-2.8623)
#   - 10% (-2.5672)
# -> adf stat is < all critical values -> non-stationary

# %% [markdown]
# now the p-value is < 0.05 -> stationary
# adf stat is < all critical values -> stationary
# -> stationary
# -> d=1 (from prior differencing): Indicates that the original series was differenced once to achieve stationarity.

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

y = df['btc_close_diff']

# Plot ACF and PACF for btc_close_diff
plot_acf(y, lags=20)
plt.show()
plot_pacf(y, lags=20)
plt.show()

# %% [markdown]
# ACF plot: large spikes at 1 -> moving average q = 1
# PACF plot: large spikes at 1 -> autoregressive p = 1
# d = 1, p = 1, q = 1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(15, 12))

# Compute correlation matrix
corr_matrix = df.corr()

# Mask lower correlations (only show abs > 0.8)
mask = np.abs(corr_matrix) < 0.8
filtered_corr = corr_matrix.copy()
filtered_corr[mask] = np.nan  # Hide lower correlations

sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, annot_kws={"size": 8})
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# Compute VIF
X = df.select_dtypes(include=[np.number])  # Select only numeric features
vif_data = pd.DataFrame()
vif_data["Feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Sort by highest VIF
vif_data = vif_data.sort_values("VIF", ascending=False)
print(vif_data.head(10))  # Display top 10 features with high VIF
# Out:
# /Users/binnu/miniforge3/envs/myenv/lib/python3.10/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning:
#
# divide by zero encountered in scalar divide
#             Feature                      VIF
# 10      btc_bb_high                      inf
# 12       btc_bb_mid                      inf
# 11       btc_bb_low                      inf
# 7          btc_macd 2920322.7329549696296453
# 8   btc_macd_signal 2567288.7045763428322971
# 9     btc_macd_diff  236831.3950804938795045
# 5        btc_ema_14   27414.6099687299029029
# 4        btc_sma_14   10615.7230184256586654
# 21             IXIC    2060.6585598916321942
# 20             GSPC    1933.2071057092223327
