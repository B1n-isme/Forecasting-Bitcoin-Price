# %% [markdown]
# ### look back values for btc_close price
# look_back_values = [1, 2, 5, 10, 20]

# %%
import joblib
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import TimeSeriesSplit
from skopt import BayesSearchCV
from skorch import NeuralNetRegressor
from sklearn.preprocessing import MinMaxScaler
from skopt.space import Real, Categorical, Integer
import math
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.base import BaseEstimator

device = torch.device("cpu")

# %%
from skorch.callbacks import Callback
from tqdm import tqdm

class TqdmProgressBar(Callback):
    def on_train_begin(self, net, **kwargs):
        self.epochs = net.max_epochs
        self.pbar = tqdm(total=self.epochs, desc="Training Progress", unit="epoch")

    def on_epoch_end(self, net, **kwargs):
        self.pbar.update(1)  # Increment the progress bar by one epoch

    def on_train_end(self, net, **kwargs):
        self.pbar.close()

# %%
train_residuals_df = pd.read_csv("../data/final/train_residuals_df.csv", parse_dates=["Date"], index_col="Date")
test_residuals_df = pd.read_csv("../data/final/test_residuals_df.csv", parse_dates=["Date"], index_col="Date")

train_residual = train_residuals_df["Residuals"]
test_residual = test_residuals_df["Residuals"]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_residual_scaled = scaler.fit_transform(train_residual.values.reshape(-1, 1))
test_residual_scaled = scaler.transform(test_residual.values.reshape(-1, 1))

# save scaler
joblib.dump(scaler, "../models/residual_scaler.pkl")
# Out:
# ['../models/residual_scaler.pkl']

# %%
train_residual_scaled = train_residual_scaled.astype(np.float32)
test_residual_scaled = test_residual_scaled.astype(np.float32)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, max_len, hidden_dim):
        super(PositionalEncoding, self).__init__()
        self.position_encoding = nn.Parameter(torch.zeros(1, max_len, hidden_dim))

    def forward(self, x):
        return self.position_encoding[:, :x.size(1), :]

# %%
import torch
import torch.nn as nn

class Seq2SeqTemporalFusionTransformer(nn.Module):
    def __init__(self, look_back, num_heads, hidden_dim, feed_forward_dim, dropout_rate,
                 num_layers=1, activation="relu", input_feature_dim=1, n_steps_ahead=1):
        super(Seq2SeqTemporalFusionTransformer, self).__init__()
        self.look_back = look_back
        self.n_steps_ahead = n_steps_ahead
        self.hidden_dim = hidden_dim

        # Input projection
        self.input_projection = nn.Linear(input_feature_dim, hidden_dim)

        # Positional encoding
        self.positional_encoding = PositionalEncoding(max_len=look_back + n_steps_ahead, hidden_dim=hidden_dim)

        # Define the activation function dynamically
        if activation == "relu":
            self.activation_fn = nn.ReLU()
        elif activation == "gelu":
            self.activation_fn = nn.GELU()
        else:
            raise ValueError(f"Unsupported activation function: {activation}")

        # Encoder layers
        self.encoder_layers = nn.ModuleList([
            nn.ModuleDict({
                "multi_head_attention": nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=num_heads, batch_first=True),
                "layer_norm1": nn.LayerNorm(hidden_dim),
                "feed_forward": nn.Sequential(
                    nn.Linear(hidden_dim, feed_forward_dim),
                    self.activation_fn,
                    nn.Dropout(dropout_rate),
                    nn.Linear(feed_forward_dim, hidden_dim)
                ),
                "layer_norm2": nn.LayerNorm(hidden_dim)
            })
            for _ in range(num_layers)
        ])

        # Decoder layers
        self.decoder_layers = nn.ModuleList([
            nn.ModuleDict({
                "self_attention": nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=num_heads, batch_first=True),
                "cross_attention": nn.MultiheadAttention(embed_dim=hidden_dim, num_heads=num_heads, batch_first=True),
                "layer_norm1": nn.LayerNorm(hidden_dim),
                "feed_forward": nn.Sequential(
                    nn.Linear(hidden_dim, feed_forward_dim),
                    self.activation_fn,
                    nn.Dropout(dropout_rate),
                    nn.Linear(feed_forward_dim, hidden_dim)
                ),
                "layer_norm2": nn.LayerNorm(hidden_dim)
            })
            for _ in range(num_layers)
        ])

        # Output layer
        self.output_layer = nn.Linear(hidden_dim, input_feature_dim)

    def forward(self, src, tgt):
        # Input projection
        src = self.input_projection(src)  # Shape: (batch_size, look_back, hidden_dim)
        tgt = self.input_projection(tgt)  # Shape: (batch_size, n_steps_ahead, hidden_dim)

        # Add positional encoding
        src = src + self.positional_encoding(src)
        tgt = tgt + self.positional_encoding(tgt)

        # Encoder
        for layer in self.encoder_layers:
            # Self-attention
            attn_output, _ = layer["multi_head_attention"](src, src, src)
            src = layer["layer_norm1"](src + attn_output)

            # Feed-forward network
            ff_output = layer["feed_forward"](src)
            src = layer["layer_norm2"](src + ff_output)

        # Decoder
        for layer in self.decoder_layers:
            # Self-attention
            self_attn_output, _ = layer["self_attention"](tgt, tgt, tgt)
            tgt = layer["layer_norm1"](tgt + self_attn_output)

            # Cross-attention (attends to encoder output)
            cross_attn_output, _ = layer["cross_attention"](tgt, src, src)
            tgt = layer["layer_norm1"](tgt + cross_attn_output)

            # Feed-forward network
            ff_output = layer["feed_forward"](tgt)
            tgt = layer["layer_norm2"](tgt + ff_output)

        # Output projection
        outputs = self.output_layer(tgt)  # Shape: (batch_size, n_steps_ahead, input_feature_dim)
        return outputs

# %% [markdown]
# ### Hyperparameters Tuning using Bayes Optimization

# %%
class Seq2SeqTemporalFusionTransformerWrapper(nn.Module):
    def __init__(self, look_back, num_heads, head_dim, feed_forward_dim, dropout_rate, num_layers, activation, n_steps_ahead):
        super(Seq2SeqTemporalFusionTransformerWrapper, self).__init__()
        self.look_back = look_back
        self.num_heads = num_heads
        self.head_dim = head_dim
        self.feed_forward_dim = feed_forward_dim
        self.dropout_rate = dropout_rate
        self.num_layers = num_layers
        self.activation = activation
        self.n_steps_ahead = n_steps_ahead
        
        # Initialize the Seq2Seq TFT model
        self.model = Seq2SeqTemporalFusionTransformer(
            look_back=look_back,
            num_heads=num_heads,
            hidden_dim=num_heads * head_dim,
            feed_forward_dim=feed_forward_dim,
            dropout_rate=dropout_rate,
            num_layers=num_layers,
            activation=activation,
            input_feature_dim=1,  # Assuming univariate time series
            n_steps_ahead=n_steps_ahead
        )

    def forward(self, src, tgt=None):
        if src.dim() == 2:
            src = src.unsqueeze(-1)  # Add feature dimension if missing
        
        # If tgt is not provided (during inference), initialize it with zeros
        if tgt is None:
            tgt = torch.zeros(src.size(0), self.n_steps_ahead, 1).to(src.device)  # Shape: (batch_size, n_steps_ahead, 1)
        
        # Ensure tgt is 3D: (batch_size, n_steps_ahead, input_feature_dim)
        if tgt.dim() == 2:
            tgt = tgt.unsqueeze(-1)  # Add feature dimension if missing
        
        # Forward pass through the model
        outputs = self.model(src, tgt)  # Shape: (batch_size, n_steps_ahead, 1)
        
        # Reshape output to (batch_size, n_steps_ahead)
        outputs = outputs.squeeze(-1)  # Remove the last dimension if it's 1
        
        return outputs
    
    def state_dict(self, *args, **kwargs):
        """
        Override to save only the state_dict of the underlying model.
        """
        return {
            'model_state_dict': self.model.state_dict(),
            'hyperparameters': {
                'look_back': self.look_back,
                'num_heads': self.num_heads,
                'head_dim': self.head_dim,
                'feed_forward_dim': self.feed_forward_dim,
                'dropout_rate': self.dropout_rate,
                'num_layers': self.num_layers,
                'activation': self.activation,
                'n_steps_ahead': self.n_steps_ahead
            }
        }

    def load_state_dict(self, state_dict, strict=True):
        """
        Override to load the state_dict into the underlying model.
        """
        self.model.load_state_dict(state_dict['model_state_dict'], strict=strict)

    def predict(self, X):
        """
        Predict on given input data (e.g., X_test or future data).
        
        Parameters:
        - X (np.ndarray or torch.Tensor): Input data of shape (batch_size, look_back).
        
        Returns:
        - np.ndarray: Predicted values of shape (batch_size, n_steps_ahead).
        """
        if not isinstance(X, torch.Tensor):
            X = torch.tensor(X, dtype=torch.float32)

        if X.dim() == 2:
            X = X.unsqueeze(-1)  # Add feature dimension if missing

        # Set the model to evaluation mode
        self.eval()

        with torch.no_grad():
            predictions = self.forward(X)  # Forward pass for prediction

        return predictions.numpy()

# %%
# Define search space for BayesSearchCV
search_space = {
    "num_heads": Categorical([2, 4, 8]),  
    "head_dim": Categorical([8, 16, 32]),  
    "feed_forward_dim": Categorical([128, 256, 512, 1024]),  
    "dropout_rate": Real(0.1, 0.4),  
    "lr": Real(5e-5, 5e-3, prior="log-uniform"), 
    "batch_size": Categorical([16, 32, 64]), 
    "num_layers": Categorical([1, 2, 3, 4]),
    "activation": Categorical(["relu", "gelu"]),
}

# %%
def create_multi_step_dataset(data, look_back, n_steps_ahead=1):
    X, y = [], []
    for i in range(len(data) - look_back - n_steps_ahead + 1):
        X.append(data[i:i + look_back, 0])  # Input sequence
        y.append(data[i + look_back:i + look_back + n_steps_ahead, 0])  # Multi-step target
    return np.array(X), np.array(y)

# Prepare training and testing datasets
look_back = 7
n_steps_ahead = 3

# Create train and test datasets
X_train, y_train = create_multi_step_dataset(train_residual_scaled, look_back, n_steps_ahead)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test, y_test = create_multi_step_dataset(test_residual_scaled, look_back, n_steps_ahead)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (722, 7, 1) (722, 3) (722, 7, 1) (722, 3)

# %%
from sklearn.base import BaseEstimator
import torch
import torch.nn as nn

class TFTEstimator(BaseEstimator):
    def __init__(self, look_back=7, num_heads=4, head_dim=16, feed_forward_dim=128,
                 dropout_rate=0.1, lr=0.001, batch_size=32, num_layers=2, activation="relu", n_steps_ahead=3):
        self.look_back = look_back
        self.num_heads = num_heads
        self.head_dim = head_dim
        self.feed_forward_dim = feed_forward_dim
        self.dropout_rate = dropout_rate
        self.lr = lr
        self.batch_size = batch_size
        self.num_layers = num_layers
        self.activation = activation
        self.n_steps_ahead = n_steps_ahead

        # Store model hyperparameters
        self.model_params = {
            "look_back": look_back,
            "num_heads": num_heads,
            "head_dim": head_dim,
            "feed_forward_dim": feed_forward_dim,
            "dropout_rate": dropout_rate,
            "num_layers": num_layers,
            "activation": activation,
            "n_steps_ahead": n_steps_ahead,
        }

        # # Store training hyperparameters
        # self.training_params = {
        #     "lr": lr,
        #     "batch_size": batch_size,
        # }
        
        # Initialize the Seq2Seq TFT model
        self.model = Seq2SeqTemporalFusionTransformerWrapper(**self.model_params)

    def fit(self, X, y):
        # Convert inputs to PyTorch tensors
        X_tensor = torch.tensor(X, dtype=torch.float32)  # Shape: (batch_size, look_back, 1)
        y_tensor = torch.tensor(y, dtype=torch.float32)  # Shape: (batch_size, n_steps_ahead, 1)
        
        # Define loss function and optimizer
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        
        # Training loop
        for epoch in range(10):  # Example: 10 epochs
            optimizer.zero_grad()
            outputs = self.model(X_tensor, y_tensor)  # Forward pass with src and tgt
            loss = criterion(outputs, y_tensor)  # Compute loss
            loss.backward()  # Backpropagation
            optimizer.step()  # Update weights
            print(f"Epoch {epoch + 1}, Loss: {loss.item()}")
        return self

    def predict(self, X):
        with torch.no_grad():
            X_tensor = torch.tensor(X, dtype=torch.float32)  # Shape: (batch_size, look_back, 1)
            predictions = self.model(X_tensor)  # Forward pass with src only (tgt is initialized internally)
        return predictions.numpy()

# %%
# Wrap the model with BayesSearchCV
bayes_search = BayesSearchCV(
    estimator=TFTEstimator(
        look_back=look_back,
        n_steps_ahead=n_steps_ahead
    ),
    search_spaces=search_space,
    n_iter=50,
    cv=TimeSeriesSplit(n_splits=5),
    scoring="neg_mean_absolute_error",
    n_jobs=-1,
    verbose=2,
    random_state=42
)

# Fit the search
bayes_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.9278357625007629
# Epoch 1, Loss: 0.0463503897190094
# Epoch 2, Loss: 0.2122383713722229
# Epoch 1, Loss: 0.18455521762371063
# Epoch 3, Loss: 0.19023002684116364
# Epoch 1, Loss: 1.1301683187484741
# Epoch 2, Loss: 0.16247206926345825
# Epoch 4, Loss: 0.3551795780658722
# Epoch 1, Loss: 0.07640371471643448
# Epoch 5, Loss: 0.33343514800071716
# Epoch 2, Loss: 0.2834385633468628
# Epoch 3, Loss: 0.029759760946035385
# Epoch 6, Loss: 0.21181060373783112
# Epoch 2, Loss: 0.16094231605529785
# Epoch 7, Loss: 0.10231553018093109
# Epoch 4, Loss: 0.04211900383234024
# Epoch 3, Loss: 0.08413039147853851
# Epoch 8, Loss: 0.046736035495996475
# Epoch 9, Loss: 0.06155575439333916
# Epoch 5, Loss: 0.07839414477348328
# Epoch 2, Loss: 0.1419248729944229
# Epoch 10, Loss: 0.10324420034885406
# [CV] END activation=relu, batch_size=64, dropout_rate=0.37986039965435026, feed_forward_dim=256, head_dim=32, lr=0.0003366722096076183, num_heads=4, num_layers=3; total time=   0.9s
# Epoch 3, Loss: 0.07242483645677567
# Epoch 4, Loss: 0.09741374105215073
# Epoch 6, Loss: 0.040778037160634995
# Epoch 7, Loss: 0.008480728603899479
# Epoch 5, Loss: 0.1129683181643486
# Epoch 3, Loss: 0.058215849101543427
# Epoch 4, Loss: 0.3219549357891083
# Epoch 8, Loss: 0.017104467377066612
# Epoch 6, Loss: 0.050007086247205734
# Epoch 9, Loss: 0.0387839749455452
# Epoch 5, Loss: 0.38952481746673584
# Epoch 4, Loss: 0.02955552004277706
# Epoch 10, Loss: 0.03814227133989334
# [CV] END activation=relu, batch_size=64, dropout_rate=0.37986039965435026, feed_forward_dim=256, head_dim=32, lr=0.0003366722096076183, num_heads=4, num_layers=3; total time=   1.1s
# Epoch 7, Loss: 0.01248136069625616
# Epoch 6, Loss: 0.28385645151138306
# Epoch 8, Loss: 0.036344245076179504
# Epoch 5, Loss: 0.06170997768640518
# Epoch 9, Loss: 0.056613024324178696
# Epoch 7, Loss: 0.13694176077842712
# Epoch 10, Loss: 0.03942210599780083
# Epoch 6, Loss: 0.054568100720644
# [CV] END activation=relu, batch_size=64, dropout_rate=0.37986039965435026, feed_forward_dim=256, head_dim=32, lr=0.0003366722096076183, num_heads=4, num_layers=3; total time=   1.3s
# Epoch 8, Loss: 0.036428842693567276
# Epoch 7, Loss: 0.02111065946519375
# Epoch 9, Loss: 0.012398171238601208
# Epoch 10, Loss: 0.04828585684299469
# [CV] END activation=relu, batch_size=64, dropout_rate=0.37986039965435026, feed_forward_dim=256, head_dim=32, lr=0.0003366722096076183, num_heads=4, num_layers=3; total time=   1.4s
# Epoch 8, Loss: 0.012574580498039722
# Epoch 9, Loss: 0.026797808706760406
# Epoch 10, Loss: 0.03377861902117729
# [CV] END activation=relu, batch_size=64, dropout_rate=0.37986039965435026, feed_forward_dim=256, head_dim=32, lr=0.0003366722096076183, num_heads=4, num_layers=3; total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.2618420124053955
# Epoch 1, Loss: 0.05965624004602432
# Epoch 1, Loss: 2.366211414337158
# Epoch 2, Loss: 0.1916547417640686
# Epoch 2, Loss: 0.05289817973971367
# Epoch 3, Loss: 0.14910268783569336
# Epoch 2, Loss: 1.9799740314483643
# Epoch 4, Loss: 0.12510725855827332
# Epoch 3, Loss: 0.04646575078368187
# Epoch 5, Loss: 0.11913701146841049
# Epoch 3, Loss: 1.6457005739212036
# Epoch 4, Loss: 0.03705785050988197
# Epoch 6, Loss: 0.11832835525274277
# Epoch 7, Loss: 0.12125404924154282
# Epoch 4, Loss: 1.3482784032821655
# Epoch 5, Loss: 0.032777562737464905
# Epoch 8, Loss: 0.11671663820743561
# Epoch 6, Loss: 0.02927154302597046
# Epoch 5, Loss: 1.0798823833465576
# Epoch 9, Loss: 0.11217121034860611
# Epoch 7, Loss: 0.022071000188589096
# Epoch 10, Loss: 0.10341700166463852
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.19102303296525253, feed_forward_dim=1024, head_dim=32, lr=6.66186589554938e-05, num_heads=2, num_layers=2; total time=   0.6s
# Epoch 6, Loss: 0.8420830965042114
# Epoch 8, Loss: 0.018528657034039497
# Epoch 7, Loss: 0.6475031971931458
# Epoch 9, Loss: 0.016620784997940063
# Epoch 8, Loss: 0.48470592498779297
# Epoch 10, Loss: 0.014248696155846119
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.19102303296525253, feed_forward_dim=1024, head_dim=32, lr=6.66186589554938e-05, num_heads=2, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.3570057153701782
# Epoch 10, Loss: 0.25323086977005005
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.19102303296525253, feed_forward_dim=1024, head_dim=32, lr=6.66186589554938e-05, num_heads=2, num_layers=2; total time=   0.9s
# Epoch 1, Loss: 0.29707735776901245
# Epoch 1, Loss: 0.05772721394896507
# Epoch 2, Loss: 0.2311064898967743
# Epoch 3, Loss: 0.1738244742155075
# Epoch 2, Loss: 0.04933830723166466
# Epoch 4, Loss: 0.14318972826004028
# Epoch 5, Loss: 0.13144434988498688
# Epoch 3, Loss: 0.0403079055249691
# Epoch 6, Loss: 0.12403704226016998
# Epoch 7, Loss: 0.12263831496238708
# Epoch 4, Loss: 0.030660009011626244
# Epoch 8, Loss: 0.1250373274087906
# Epoch 9, Loss: 0.11577631533145905
# Epoch 5, Loss: 0.026370050385594368
# Epoch 10, Loss: 0.11167538911104202
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.19102303296525253, feed_forward_dim=1024, head_dim=32, lr=6.66186589554938e-05, num_heads=2, num_layers=2; total time=   0.6s
# Epoch 6, Loss: 0.020395630970597267
# Epoch 7, Loss: 0.017799999564886093
# Epoch 8, Loss: 0.014114908874034882
# Epoch 9, Loss: 0.012042567133903503
# Epoch 10, Loss: 0.011605185456573963
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.19102303296525253, feed_forward_dim=1024, head_dim=32, lr=6.66186589554938e-05, num_heads=2, num_layers=2; total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.9486886262893677
# Epoch 1, Loss: 1.3962692022323608
# Epoch 2, Loss: 0.17923539876937866
# Epoch 2, Loss: 0.2803446352481842
# Epoch 3, Loss: 0.14034487307071686
# Epoch 3, Loss: 0.24666807055473328
# Epoch 4, Loss: 0.30707138776779175
# Epoch 4, Loss: 0.48134270310401917
# Epoch 5, Loss: 0.33893346786499023
# Epoch 6, Loss: 0.2548103630542755
# Epoch 5, Loss: 0.48064863681793213
# Epoch 7, Loss: 0.14243043959140778
# Epoch 6, Loss: 0.326253741979599
# Epoch 8, Loss: 0.062099017202854156
# Epoch 7, Loss: 0.15951719880104065
# Epoch 9, Loss: 0.0354139506816864
# Epoch 8, Loss: 0.06574976444244385
# Epoch 10, Loss: 0.05286683887243271
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13145774756581108, feed_forward_dim=256, head_dim=8, lr=0.00040392496121433854, num_heads=2, num_layers=4; total time=   0.8s
# Epoch 9, Loss: 0.05667217820882797
# Epoch 10, Loss: 0.09865467250347137
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13145774756581108, feed_forward_dim=256, head_dim=8, lr=0.00040392496121433854, num_heads=2, num_layers=4; total time=   1.0s
# Epoch 1, Loss: 0.1528727114200592
# Epoch 1, Loss: 0.8117848038673401
# Epoch 2, Loss: 0.0927380621433258
# Epoch 1, Loss: 0.18444424867630005
# Epoch 3, Loss: 0.11420150846242905
# Epoch 2, Loss: 0.10156647115945816
# Epoch 4, Loss: 0.034483931958675385
# Epoch 5, Loss: 0.020361512899398804
# Epoch 2, Loss: 0.20923207700252533
# Epoch 3, Loss: 0.13833098113536835
# Epoch 6, Loss: 0.04964500665664673
# Epoch 7, Loss: 0.05215878412127495
# Epoch 4, Loss: 0.3195372521877289
# Epoch 8, Loss: 0.022916944697499275
# Epoch 3, Loss: 0.1356183886528015
# Epoch 9, Loss: 0.00745216803625226
# Epoch 5, Loss: 0.29611942172050476
# Epoch 10, Loss: 0.017118481919169426
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13145774756581108, feed_forward_dim=256, head_dim=8, lr=0.00040392496121433854, num_heads=2, num_layers=4; total time=   0.7s
# Epoch 4, Loss: 0.044987477362155914
# Epoch 6, Loss: 0.16785487532615662
# Epoch 7, Loss: 0.062224239110946655
# Epoch 5, Loss: 0.06431695818901062
# Epoch 8, Loss: 0.02585754171013832
# Epoch 6, Loss: 0.08205345273017883
# Epoch 9, Loss: 0.05294545367360115
# Epoch 10, Loss: 0.0942615196108818
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13145774756581108, feed_forward_dim=256, head_dim=8, lr=0.00040392496121433854, num_heads=2, num_layers=4; total time=   0.8s
# Epoch 7, Loss: 0.04627310112118721
# Epoch 8, Loss: 0.011678514070808887
# Epoch 9, Loss: 0.018305417150259018
# Epoch 10, Loss: 0.03771171718835831
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13145774756581108, feed_forward_dim=256, head_dim=8, lr=0.00040392496121433854, num_heads=2, num_layers=4; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.15624123811721802
# Epoch 1, Loss: 0.0734531506896019
# Epoch 1, Loss: 0.5738672614097595
# Epoch 2, Loss: 0.1286223828792572
# Epoch 2, Loss: 0.03613260015845299
# Epoch 3, Loss: 0.11162387579679489
# Epoch 2, Loss: 0.400155633687973
# Epoch 4, Loss: 0.09576158970594406
# Epoch 3, Loss: 0.0346708744764328
# Epoch 5, Loss: 0.07876162976026535
# Epoch 3, Loss: 0.26456624269485474
# Epoch 4, Loss: 0.03923071548342705
# Epoch 6, Loss: 0.06351962685585022
# Epoch 5, Loss: 0.037461768835783005
# Epoch 7, Loss: 0.052907489240169525
# Epoch 4, Loss: 0.16220349073410034
# Epoch 8, Loss: 0.04520007222890854
# Epoch 6, Loss: 0.027430664747953415
# Epoch 5, Loss: 0.0997791737318039
# Epoch 9, Loss: 0.03643542900681496
# Epoch 7, Loss: 0.020071614533662796
# Epoch 10, Loss: 0.031010201200842857
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.27941412325363846, feed_forward_dim=1024, head_dim=16, lr=7.760328091464899e-05, num_heads=8, num_layers=4; total time=   0.6s
# Epoch 6, Loss: 0.06744115799665451
# Epoch 8, Loss: 0.015195133164525032
# Epoch 7, Loss: 0.06053844466805458
# Epoch 9, Loss: 0.016269497573375702
# Epoch 10, Loss: 0.017340922728180885
# Epoch 8, Loss: 0.0706997737288475
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.27941412325363846, feed_forward_dim=1024, head_dim=16, lr=7.760328091464899e-05, num_heads=8, num_layers=4; total time=   0.8s
# Epoch 9, Loss: 0.09017416834831238
# Epoch 10, Loss: 0.10596045106649399
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.27941412325363846, feed_forward_dim=1024, head_dim=16, lr=7.760328091464899e-05, num_heads=8, num_layers=4; total time=   1.0s
# Epoch 1, Loss: 0.1698451191186905
# Epoch 1, Loss: 0.40160879492759705
# Epoch 2, Loss: 0.08454082906246185
# Epoch 3, Loss: 0.037364352494478226
# Epoch 2, Loss: 0.27953848242759705
# Epoch 4, Loss: 0.02067974954843521
# Epoch 5, Loss: 0.028619805350899696
# Epoch 3, Loss: 0.19658927619457245
# Epoch 6, Loss: 0.038674935698509216
# Epoch 7, Loss: 0.049267273396253586
# Epoch 4, Loss: 0.1388174146413803
# Epoch 8, Loss: 0.05222678184509277
# Epoch 9, Loss: 0.04286086931824684
# Epoch 5, Loss: 0.10765516757965088
# Epoch 10, Loss: 0.03407621756196022
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.27941412325363846, feed_forward_dim=1024, head_dim=16, lr=7.760328091464899e-05, num_heads=8, num_layers=4; total time=   0.6s
# Epoch 6, Loss: 0.09954285621643066
# Epoch 7, Loss: 0.10206475853919983
# Epoch 8, Loss: 0.1116216853260994
# Epoch 9, Loss: 0.11825702339410782
# Epoch 10, Loss: 0.11963056772947311
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.27941412325363846, feed_forward_dim=1024, head_dim=16, lr=7.760328091464899e-05, num_heads=8, num_layers=4; total time=   0.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 3.3911118507385254
# Epoch 1, Loss: 0.3800370693206787
# Epoch 2, Loss: 0.5917465686798096
# Epoch 3, Loss: 1.1024274826049805
# Epoch 1, Loss: 2.3404932022094727
# Epoch 2, Loss: 2.1053719520568848
# Epoch 4, Loss: 0.44173097610473633
# Epoch 1, Loss: 0.2496408224105835
# Epoch 5, Loss: 0.059275850653648376
# Epoch 3, Loss: 0.20527483522891998
# Epoch 1, Loss: 0.11844706535339355
# Epoch 2, Loss: 0.9427340626716614
# Epoch 6, Loss: 0.10671378672122955
# Epoch 7, Loss: 0.2606733441352844
# Epoch 4, Loss: 0.26970627903938293
# Epoch 8, Loss: 0.28162193298339844
# Epoch 2, Loss: 2.359783172607422
# Epoch 3, Loss: 0.9063587188720703
# Epoch 9, Loss: 0.19722135365009308
# Epoch 5, Loss: 0.5787928104400635
# Epoch 10, Loss: 0.0842929407954216
# Epoch 2, Loss: 0.4348812401294708
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.25798607113830774, feed_forward_dim=512, head_dim=32, lr=0.0013584144936851423, num_heads=4, num_layers=3; total time=   0.2s
# Epoch 6, Loss: 0.37075552344322205
# Epoch 4, Loss: 0.23809583485126495
# Epoch 3, Loss: 0.6614503264427185
# Epoch 7, Loss: 0.10696545988321304
# Epoch 5, Loss: 0.05247851088643074
# Epoch 8, Loss: 0.023626839742064476
# Epoch 3, Loss: 0.7700269818305969
# Epoch 4, Loss: 0.03371724486351013
# Epoch 9, Loss: 0.0910167396068573
# Epoch 6, Loss: 0.19662895798683167
# Epoch 10, Loss: 0.17755115032196045
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.25798607113830774, feed_forward_dim=512, head_dim=32, lr=0.0013584144936851423, num_heads=4, num_layers=3; total time=   0.4s
# Epoch 5, Loss: 0.45009514689445496
# Epoch 4, Loss: 0.41407477855682373
# Epoch 7, Loss: 0.29039961099624634
# Epoch 8, Loss: 0.2428637444972992
# Epoch 6, Loss: 0.5769075751304626
# Epoch 5, Loss: 0.01794874668121338
# Epoch 9, Loss: 0.13506574928760529
# Epoch 7, Loss: 0.34218794107437134
# Epoch 10, Loss: 0.051250141113996506
# Epoch 6, Loss: 0.14259107410907745
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.25798607113830774, feed_forward_dim=512, head_dim=32, lr=0.0013584144936851423, num_heads=4, num_layers=3; total time=   0.6s
# Epoch 8, Loss: 0.11000296473503113
# Epoch 7, Loss: 0.27402758598327637
# Epoch 9, Loss: 0.034487780183553696
# Epoch 10, Loss: 0.08687729388475418
# Epoch 8, Loss: 0.1873716413974762
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.25798607113830774, feed_forward_dim=512, head_dim=32, lr=0.0013584144936851423, num_heads=4, num_layers=3; total time=   0.7s
# Epoch 9, Loss: 0.059134263545274734
# Epoch 10, Loss: 0.023707840591669083
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.25798607113830774, feed_forward_dim=512, head_dim=32, lr=0.0013584144936851423, num_heads=4, num_layers=3; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.1461402326822281
# Epoch 2, Loss: 0.11231239140033722
# Epoch 1, Loss: 0.06309022009372711
# Epoch 3, Loss: 0.09164927899837494
# Epoch 1, Loss: 0.3994714021682739
# Epoch 4, Loss: 0.03472033888101578
# Epoch 2, Loss: 0.10513664782047272
# Epoch 5, Loss: 0.028316445648670197
# Epoch 1, Loss: 1.1201037168502808
# Epoch 3, Loss: 0.024132242426276207
# Epoch 6, Loss: 0.03526267409324646
# Epoch 1, Loss: 1.1510032415390015
# Epoch 2, Loss: 0.16547824442386627
# Epoch 7, Loss: 0.023023147135972977
# Epoch 4, Loss: 0.055676624178886414
# Epoch 8, Loss: 0.01294922549277544
# Epoch 2, Loss: 0.40868186950683594
# Epoch 9, Loss: 0.01767251081764698
# Epoch 5, Loss: 0.051700446754693985
# Epoch 3, Loss: 0.24279087781906128
# Epoch 10, Loss: 0.02908829040825367
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.1490821535915651, feed_forward_dim=128, head_dim=32, lr=0.0002780542645592738, num_heads=4, num_layers=3; total time=   0.2s
# Epoch 2, Loss: 0.3372686505317688
# Epoch 6, Loss: 0.018837329000234604
# Epoch 3, Loss: 0.09829820692539215
# Epoch 4, Loss: 0.21473465859889984
# Epoch 7, Loss: 0.01973939687013626
# Epoch 8, Loss: 0.03891710191965103
# Epoch 5, Loss: 0.13150222599506378
# Epoch 4, Loss: 0.11822107434272766
# Epoch 3, Loss: 0.07775985449552536
# Epoch 9, Loss: 0.036518681794404984
# Epoch 6, Loss: 0.08153821527957916
# Epoch 10, Loss: 0.02027014270424843
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.1490821535915651, feed_forward_dim=128, head_dim=32, lr=0.0002780542645592738, num_heads=4, num_layers=3; total time=   0.4s
# Epoch 5, Loss: 0.24955689907073975
# Epoch 4, Loss: 0.19915352761745453
# Epoch 7, Loss: 0.08388129621744156
# Epoch 6, Loss: 0.3162563741207123
# Epoch 8, Loss: 0.09496398270130157
# Epoch 5, Loss: 0.3479537069797516
# Epoch 9, Loss: 0.08778858929872513
# Epoch 7, Loss: 0.2930102050304413
# Epoch 10, Loss: 0.05957577005028725
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.1490821535915651, feed_forward_dim=128, head_dim=32, lr=0.0002780542645592738, num_heads=4, num_layers=3; total time=   0.6s
# Epoch 6, Loss: 0.3600287139415741
# Epoch 8, Loss: 0.2145620435476303
# Epoch 9, Loss: 0.12918135523796082
# Epoch 7, Loss: 0.27029553055763245
# Epoch 10, Loss: 0.06428443640470505
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.1490821535915651, feed_forward_dim=128, head_dim=32, lr=0.0002780542645592738, num_heads=4, num_layers=3; total time=   0.8s
# Epoch 8, Loss: 0.1568780243396759
# Epoch 9, Loss: 0.07164198160171509
# Epoch 10, Loss: 0.03642917424440384
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.1490821535915651, feed_forward_dim=128, head_dim=32, lr=0.0002780542645592738, num_heads=4, num_layers=3; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.5710494518280029
# Epoch 2, Loss: 0.2879002094268799
# Epoch 1, Loss: 0.23511040210723877
# Epoch 3, Loss: 0.36387401819229126
# Epoch 1, Loss: 0.07325886189937592
# Epoch 2, Loss: 0.5686455368995667
# Epoch 4, Loss: 0.14080595970153809
# Epoch 5, Loss: 0.0325520783662796
# Epoch 1, Loss: 1.6622031927108765
# Epoch 3, Loss: 0.2341831475496292
# Epoch 1, Loss: 1.7509846687316895
# Epoch 6, Loss: 0.07812421768903732
# Epoch 2, Loss: 1.0168395042419434
# Epoch 7, Loss: 0.12705887854099274
# Epoch 4, Loss: 0.02088652178645134
# Epoch 8, Loss: 0.11155620217323303
# Epoch 2, Loss: 0.07330234348773956
# Epoch 9, Loss: 0.0518161840736866
# Epoch 5, Loss: 0.13091474771499634
# Epoch 3, Loss: 0.011095477268099785
# Epoch 10, Loss: 0.012484967708587646
# Epoch 2, Loss: 0.10713537037372589
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.2077068795764212, feed_forward_dim=1024, head_dim=16, lr=0.0007730544322582723, num_heads=4, num_layers=2; total time=   0.2s
# Epoch 6, Loss: 0.20352791249752045
# Epoch 4, Loss: 0.4810929298400879
# Epoch 3, Loss: 0.4824513792991638
# Epoch 7, Loss: 0.1348656266927719
# Epoch 8, Loss: 0.04700608551502228
# Epoch 3, Loss: 0.7962974905967712
# Epoch 5, Loss: 0.4921012818813324
# Epoch 9, Loss: 0.017117178067564964
# Epoch 4, Loss: 0.5794034600257874
# Epoch 10, Loss: 0.0443497858941555
# Epoch 6, Loss: 0.17659902572631836
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.2077068795764212, feed_forward_dim=1024, head_dim=16, lr=0.0007730544322582723, num_heads=4, num_layers=2; total time=   0.4s
# Epoch 4, Loss: 0.6517301797866821
# Epoch 5, Loss: 0.34245553612709045
# Epoch 7, Loss: 0.010122397914528847
# Epoch 5, Loss: 0.24501124024391174
# Epoch 6, Loss: 0.12175844609737396
# Epoch 8, Loss: 0.06394792348146439
# Epoch 9, Loss: 0.17109256982803345
# Epoch 7, Loss: 0.04252273216843605
# Epoch 6, Loss: 0.034655310213565826
# Epoch 10, Loss: 0.20028464496135712
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.2077068795764212, feed_forward_dim=1024, head_dim=16, lr=0.0007730544322582723, num_heads=4, num_layers=2; total time=   0.6s
# Epoch 8, Loss: 0.06677713245153427
# Epoch 7, Loss: 0.07079807668924332
# Epoch 9, Loss: 0.12357626855373383
# Epoch 8, Loss: 0.19587825238704681
# Epoch 10, Loss: 0.15518009662628174
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.2077068795764212, feed_forward_dim=1024, head_dim=16, lr=0.0007730544322582723, num_heads=4, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.2601865828037262
# Epoch 10, Loss: 0.22518540918827057
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.2077068795764212, feed_forward_dim=1024, head_dim=16, lr=0.0007730544322582723, num_heads=4, num_layers=2; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.21951261162757874
# Epoch 2, Loss: 0.18536220490932465
# Epoch 1, Loss: 0.42872026562690735
# Epoch 3, Loss: 0.16119608283042908
# Epoch 1, Loss: 0.9719489216804504
# Epoch 4, Loss: 0.14690664410591125
# Epoch 2, Loss: 0.29820120334625244
# Epoch 1, Loss: 2.210470199584961
# Epoch 5, Loss: 0.14018547534942627
# Epoch 6, Loss: 0.13045832514762878
# Epoch 2, Loss: 0.7479498386383057
# Epoch 3, Loss: 0.19857439398765564
# Epoch 1, Loss: 0.8700863718986511
# Epoch 7, Loss: 0.1126525029540062
# Epoch 8, Loss: 0.1032257005572319
# Epoch 4, Loss: 0.12478543817996979
# Epoch 2, Loss: 1.9095786809921265
# Epoch 9, Loss: 0.08828184008598328
# Epoch 3, Loss: 0.5655782222747803
# Epoch 10, Loss: 0.08178283274173737
# Epoch 5, Loss: 0.08013804256916046
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.24894001107901506, feed_forward_dim=1024, head_dim=8, lr=6.32760137409658e-05, num_heads=4, num_layers=1; total time=   0.2s
# Epoch 2, Loss: 0.7132036685943604
# Epoch 4, Loss: 0.4002153277397156
# Epoch 3, Loss: 1.6172218322753906
# Epoch 6, Loss: 0.0636080652475357
# Epoch 7, Loss: 0.06065233051776886
# Epoch 5, Loss: 0.2737659811973572
# Epoch 4, Loss: 1.3570584058761597
# Epoch 8, Loss: 0.07450074702501297
# Epoch 3, Loss: 0.5750413537025452
# Epoch 6, Loss: 0.1729246973991394
# Epoch 9, Loss: 0.08401095867156982
# Epoch 5, Loss: 1.1179816722869873
# Epoch 7, Loss: 0.09736006706953049
# Epoch 10, Loss: 0.09537716209888458
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.24894001107901506, feed_forward_dim=1024, head_dim=8, lr=6.32760137409658e-05, num_heads=4, num_layers=1; total time=   0.4s
# Epoch 4, Loss: 0.45148414373397827
# Epoch 8, Loss: 0.04758809134364128
# Epoch 6, Loss: 0.9005402326583862
# Epoch 9, Loss: 0.021719690412282944
# Epoch 5, Loss: 0.3483942151069641
# Epoch 7, Loss: 0.7172402739524841
# Epoch 10, Loss: 0.010617980733513832
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.24894001107901506, feed_forward_dim=1024, head_dim=8, lr=6.32760137409658e-05, num_heads=4, num_layers=1; total time=   0.6s
# Epoch 8, Loss: 0.5532980561256409
# Epoch 6, Loss: 0.27140337228775024
# Epoch 9, Loss: 0.4182029664516449
# Epoch 7, Loss: 0.202316552400589
# Epoch 10, Loss: 0.303741991519928
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.24894001107901506, feed_forward_dim=1024, head_dim=8, lr=6.32760137409658e-05, num_heads=4, num_layers=1; total time=   0.7s
# Epoch 8, Loss: 0.154164120554924
# Epoch 9, Loss: 0.12142396718263626
# Epoch 10, Loss: 0.1005455031991005
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.24894001107901506, feed_forward_dim=1024, head_dim=8, lr=6.32760137409658e-05, num_heads=4, num_layers=1; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.2614765763282776
# Epoch 2, Loss: 0.09570688009262085
# Epoch 1, Loss: 0.14855246245861053
# Epoch 3, Loss: 0.02008250169456005
# Epoch 1, Loss: 0.10494983196258545
# Epoch 4, Loss: 0.018980175256729126
# Epoch 2, Loss: 0.09616654366254807
# Epoch 5, Loss: 0.050862107425928116
# Epoch 1, Loss: 0.21667757630348206
# Epoch 6, Loss: 0.0745173767209053
# Epoch 2, Loss: 0.058557506650686264
# Epoch 3, Loss: 0.09010791033506393
# Epoch 1, Loss: 0.18436919152736664
# Epoch 7, Loss: 0.07800150662660599
# Epoch 8, Loss: 0.06347667425870895
# Epoch 4, Loss: 0.07444357872009277
# Epoch 3, Loss: 0.06732712686061859
# Epoch 9, Loss: 0.03549598157405853
# Epoch 2, Loss: 0.0966489389538765
# Epoch 10, Loss: 0.019416673108935356
# Epoch 5, Loss: 0.04943092539906502
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.3614955785389645, feed_forward_dim=256, head_dim=16, lr=0.00013237274622277244, num_heads=2, num_layers=2; total time=   0.2s
# Epoch 2, Loss: 0.07090511173009872
# Epoch 4, Loss: 0.057304058223962784
# Epoch 6, Loss: 0.02977309189736843
# Epoch 3, Loss: 0.06401636451482773
# Epoch 7, Loss: 0.024791603907942772
# Epoch 5, Loss: 0.037229932844638824
# Epoch 3, Loss: 0.04050006344914436
# Epoch 8, Loss: 0.024017218500375748
# Epoch 4, Loss: 0.08313018828630447
# Epoch 6, Loss: 0.025825699791312218
# Epoch 9, Loss: 0.02030174806714058
# Epoch 10, Loss: 0.014590547420084476
# Epoch 7, Loss: 0.022949688136577606
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.3614955785389645, feed_forward_dim=256, head_dim=16, lr=0.00013237274622277244, num_heads=2, num_layers=2; total time=   0.4s
# Epoch 4, Loss: 0.05922369286417961
# Epoch 5, Loss: 0.0989808440208435
# Epoch 8, Loss: 0.023690786212682724
# Epoch 6, Loss: 0.08795647323131561
# Epoch 5, Loss: 0.06979052722454071
# Epoch 9, Loss: 0.020272409543395042
# Epoch 10, Loss: 0.013516535051167011
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.3614955785389645, feed_forward_dim=256, head_dim=16, lr=0.00013237274622277244, num_heads=2, num_layers=2; total time=   0.6s
# Epoch 7, Loss: 0.0684441402554512
# Epoch 6, Loss: 0.06573871523141861
# Epoch 8, Loss: 0.04381667822599411
# Epoch 7, Loss: 0.04486427456140518
# Epoch 9, Loss: 0.030566023662686348
# Epoch 8, Loss: 0.025949867442250252
# Epoch 10, Loss: 0.029055889695882797
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.3614955785389645, feed_forward_dim=256, head_dim=16, lr=0.00013237274622277244, num_heads=2, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.013494211249053478
# Epoch 10, Loss: 0.011482922360301018
# [CV] END activation=gelu, batch_size=64, dropout_rate=0.3614955785389645, feed_forward_dim=256, head_dim=16, lr=0.00013237274622277244, num_heads=2, num_layers=2; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 1.448856234550476
# Epoch 2, Loss: 0.8936569690704346
# Epoch 1, Loss: 0.1443823128938675
# Epoch 3, Loss: 0.48363086581230164
# Epoch 1, Loss: 0.35993483662605286
# Epoch 4, Loss: 0.23582595586776733
# Epoch 2, Loss: 0.095800019800663
# Epoch 1, Loss: 1.2422510385513306
# Epoch 5, Loss: 0.1067141741514206
# Epoch 2, Loss: 0.13182243704795837
# Epoch 1, Loss: 0.631779134273529
# Epoch 6, Loss: 0.07556940615177155
# Epoch 3, Loss: 0.062125951051712036
# Epoch 7, Loss: 0.10935325920581818
# Epoch 8, Loss: 0.16374264657497406
# Epoch 4, Loss: 0.03681511431932449
# Epoch 2, Loss: 0.6564284563064575
# Epoch 3, Loss: 0.11654672771692276
# Epoch 9, Loss: 0.21236200630664825
# Epoch 10, Loss: 0.23626302182674408
# Epoch 5, Loss: 0.024657536298036575
# [CV] END activation=relu, batch_size=64, dropout_rate=0.32238482331040824, feed_forward_dim=256, head_dim=16, lr=0.00017717388242560026, num_heads=2, num_layers=1; total time=   0.3s
# Epoch 2, Loss: 0.4308106601238251
# Epoch 4, Loss: 0.15415595471858978
# Epoch 6, Loss: 0.018263889476656914
# Epoch 3, Loss: 0.28267207741737366
# Epoch 7, Loss: 0.01723969168961048
# Epoch 5, Loss: 0.15148711204528809
# Epoch 3, Loss: 0.35636717081069946
# Epoch 8, Loss: 0.020409472286701202
# Epoch 4, Loss: 0.09594547003507614
# Epoch 6, Loss: 0.1060037687420845
# Epoch 9, Loss: 0.02302483282983303
# Epoch 10, Loss: 0.025184927508234978
# Epoch 4, Loss: 0.32813510298728943
# [CV] END activation=relu, batch_size=64, dropout_rate=0.32238482331040824, feed_forward_dim=256, head_dim=16, lr=0.00017717388242560026, num_heads=2, num_layers=1; total time=   0.5s
# Epoch 5, Loss: 0.054589614272117615
# Epoch 7, Loss: 0.05936513468623161
# Epoch 8, Loss: 0.03184789419174194
# Epoch 6, Loss: 0.10376761853694916
# Epoch 5, Loss: 0.31054314970970154
# Epoch 9, Loss: 0.031815435737371445
# Epoch 7, Loss: 0.18167458474636078
# Epoch 10, Loss: 0.04377349093556404
# Epoch 6, Loss: 0.27264106273651123
# [CV] END activation=relu, batch_size=64, dropout_rate=0.32238482331040824, feed_forward_dim=256, head_dim=16, lr=0.00017717388242560026, num_heads=2, num_layers=1; total time=   0.6s
# Epoch 8, Loss: 0.23386187851428986
# Epoch 7, Loss: 0.22937116026878357
# Epoch 9, Loss: 0.2476630061864853
# Epoch 8, Loss: 0.18666957318782806
# Epoch 10, Loss: 0.22916142642498016
# [CV] END activation=relu, batch_size=64, dropout_rate=0.32238482331040824, feed_forward_dim=256, head_dim=16, lr=0.00017717388242560026, num_heads=2, num_layers=1; total time=   0.8s
# Epoch 9, Loss: 0.15210342407226562
# Epoch 10, Loss: 0.132374107837677
# [CV] END activation=relu, batch_size=64, dropout_rate=0.32238482331040824, feed_forward_dim=256, head_dim=16, lr=0.00017717388242560026, num_heads=2, num_layers=1; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.43913909792900085
# Epoch 2, Loss: 0.1004176214337349
# Epoch 1, Loss: 0.14414840936660767
# Epoch 3, Loss: 0.2637600004673004
# Epoch 4, Loss: 0.20813651382923126
# Epoch 1, Loss: 0.3033751845359802
# Epoch 2, Loss: 0.2722407579421997
# Epoch 5, Loss: 0.07988113909959793
# Epoch 3, Loss: 0.11031270027160645
# Epoch 6, Loss: 0.028963446617126465
# Epoch 1, Loss: 0.6075016260147095
# Epoch 2, Loss: 0.04586208239197731
# Epoch 1, Loss: 2.3342244625091553
# Epoch 7, Loss: 0.061291906982660294
# Epoch 4, Loss: 0.04032209888100624
# Epoch 8, Loss: 0.09810902923345566
# Epoch 2, Loss: 0.08481989055871964
# Epoch 9, Loss: 0.08728121966123581
# Epoch 3, Loss: 0.15642930567264557
# Epoch 5, Loss: 0.09689366072416306
# Epoch 10, Loss: 0.04863850399851799
# [CV] END activation=relu, batch_size=16, dropout_rate=0.10055098223653203, feed_forward_dim=256, head_dim=8, lr=0.0004027735950174732, num_heads=2, num_layers=4; total time=   0.3s
# Epoch 2, Loss: 0.7288490533828735
# Epoch 6, Loss: 0.09101855754852295
# Epoch 4, Loss: 0.1511116921901703
# Epoch 3, Loss: 0.21551929414272308
# Epoch 7, Loss: 0.03249744698405266
# Epoch 5, Loss: 0.06740298867225647
# Epoch 8, Loss: 0.01243908703327179
# Epoch 3, Loss: 0.07584134489297867
# Epoch 4, Loss: 0.283883273601532
# Epoch 9, Loss: 0.03556448966264725
# Epoch 6, Loss: 0.01781916618347168
# Epoch 10, Loss: 0.05641627311706543
# [CV] END activation=relu, batch_size=16, dropout_rate=0.10055098223653203, feed_forward_dim=256, head_dim=8, lr=0.0004027735950174732, num_heads=2, num_layers=4; total time=   0.4s
# Epoch 7, Loss: 0.029645372182130814
# Epoch 4, Loss: 0.16092754900455475
# Epoch 5, Loss: 0.18595784902572632
# Epoch 8, Loss: 0.062423016875982285
# Epoch 6, Loss: 0.07791074365377426
# Epoch 5, Loss: 0.43395304679870605
# Epoch 9, Loss: 0.07177405804395676
# Epoch 7, Loss: 0.03416864573955536
# Epoch 10, Loss: 0.05019550025463104
# [CV] END activation=relu, batch_size=16, dropout_rate=0.10055098223653203, feed_forward_dim=256, head_dim=8, lr=0.0004027735950174732, num_heads=2, num_layers=4; total time=   0.6s
# Epoch 6, Loss: 0.545133113861084
# Epoch 8, Loss: 0.05119568482041359
# Epoch 7, Loss: 0.4803502857685089
# Epoch 9, Loss: 0.08963541686534882
# Epoch 10, Loss: 0.10309086740016937
# Epoch 8, Loss: 0.33388087153434753
# [CV] END activation=relu, batch_size=16, dropout_rate=0.10055098223653203, feed_forward_dim=256, head_dim=8, lr=0.0004027735950174732, num_heads=2, num_layers=4; total time=   0.8s
# Epoch 9, Loss: 0.18582719564437866
# Epoch 10, Loss: 0.07791322469711304
# [CV] END activation=relu, batch_size=16, dropout_rate=0.10055098223653203, feed_forward_dim=256, head_dim=8, lr=0.0004027735950174732, num_heads=2, num_layers=4; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.15381133556365967
# Epoch 2, Loss: 0.25633859634399414
# Epoch 1, Loss: 2.1970441341400146
# Epoch 3, Loss: 7.509040355682373
# Epoch 2, Loss: 9.822097778320312
# Epoch 1, Loss: 1.5959404706954956
# Epoch 4, Loss: 1.2391324043273926
# Epoch 1, Loss: 0.07424744963645935
# Epoch 5, Loss: 0.1480640172958374
# Epoch 3, Loss: 3.7300024032592773
# Epoch 1, Loss: 1.490073561668396
# Epoch 6, Loss: 0.8121674060821533
# Epoch 2, Loss: 6.1200337409973145
# Epoch 4, Loss: 0.4205183684825897
# Epoch 7, Loss: 0.6345494389533997
# Epoch 2, Loss: 10.808029174804688
# Epoch 8, Loss: 0.22579151391983032
# Epoch 3, Loss: 1.462560772895813
# Epoch 5, Loss: 0.2905631959438324
# Epoch 2, Loss: 8.478477478027344
# Epoch 9, Loss: 0.07173945009708405
# Epoch 10, Loss: 0.16716203093528748
# Epoch 6, Loss: 0.7983863353729248
# [CV] END activation=relu, batch_size=32, dropout_rate=0.20143212704142233, feed_forward_dim=512, head_dim=8, lr=0.004566793114437616, num_heads=8, num_layers=2; total time=   0.3s
# Epoch 3, Loss: 1.3396451473236084
# Epoch 4, Loss: 0.06090207025408745
# Epoch 7, Loss: 0.6053280234336853
# Epoch 3, Loss: 2.4682397842407227
# Epoch 5, Loss: 0.5479536056518555
# Epoch 8, Loss: 0.22696475684642792
# Epoch 4, Loss: 1.0353256464004517
# Epoch 9, Loss: 0.0667274072766304
# Epoch 6, Loss: 0.5651800632476807
# Epoch 10, Loss: 0.13957232236862183
# Epoch 5, Loss: 0.8835573196411133
# Epoch 4, Loss: 0.06416270136833191
# [CV] END activation=relu, batch_size=32, dropout_rate=0.20143212704142233, feed_forward_dim=512, head_dim=8, lr=0.004566793114437616, num_heads=8, num_layers=2; total time=   0.4s
# Epoch 7, Loss: 0.26173341274261475
# Epoch 6, Loss: 0.23331521451473236
# Epoch 8, Loss: 0.07856776565313339
# Epoch 5, Loss: 0.8947681784629822
# Epoch 9, Loss: 0.09009645879268646
# Epoch 7, Loss: 0.04610373079776764
# Epoch 6, Loss: 0.6520669460296631
# Epoch 10, Loss: 0.1629321426153183
# [CV] END activation=relu, batch_size=32, dropout_rate=0.20143212704142233, feed_forward_dim=512, head_dim=8, lr=0.004566793114437616, num_heads=8, num_layers=2; total time=   0.6s
# Epoch 8, Loss: 0.12053396552801132
# Epoch 7, Loss: 0.18596436083316803
# Epoch 9, Loss: 0.18181216716766357
# Epoch 8, Loss: 0.05602169781923294
# Epoch 10, Loss: 0.15441292524337769
# [CV] END activation=relu, batch_size=32, dropout_rate=0.20143212704142233, feed_forward_dim=512, head_dim=8, lr=0.004566793114437616, num_heads=8, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.1426960825920105
# Epoch 10, Loss: 0.20426231622695923
# [CV] END activation=relu, batch_size=32, dropout_rate=0.20143212704142233, feed_forward_dim=512, head_dim=8, lr=0.004566793114437616, num_heads=8, num_layers=2; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.1390056610107422
# Epoch 2, Loss: 6.525790691375732
# Epoch 1, Loss: 0.020733272656798363
# Epoch 3, Loss: 1.5006077289581299
# Epoch 1, Loss: 0.46380552649497986
# Epoch 4, Loss: 0.05264566093683243
# Epoch 2, Loss: 10.423851013183594
# Epoch 5, Loss: 0.8093129992485046
# Epoch 1, Loss: 0.5453639626502991
# Epoch 6, Loss: 0.8183568120002747
# Epoch 2, Loss: 7.998568534851074
# Epoch 3, Loss: 0.26124170422554016
# Epoch 1, Loss: 0.29457759857177734
# Epoch 7, Loss: 0.41982677578926086
# Epoch 8, Loss: 0.13521480560302734
# Epoch 4, Loss: 3.1288440227508545
# Epoch 9, Loss: 0.0670131966471672
# Epoch 3, Loss: 1.8955882787704468
# Epoch 2, Loss: 7.63383150100708
# Epoch 10, Loss: 0.1334509253501892
# Epoch 5, Loss: 1.4801963567733765
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3922815173110077, feed_forward_dim=256, head_dim=8, lr=0.0032083479827669232, num_heads=4, num_layers=2; total time=   0.3s
# Epoch 2, Loss: 9.68160343170166
# Epoch 4, Loss: 0.09026617556810379
# Epoch 6, Loss: 0.24269960820674896
# Epoch 3, Loss: 2.265455961227417
# Epoch 7, Loss: 0.05501909926533699
# Epoch 5, Loss: 0.4473700523376465
# Epoch 8, Loss: 0.2620246112346649
# Epoch 3, Loss: 3.0943567752838135
# Epoch 4, Loss: 0.11731306463479996
# Epoch 9, Loss: 0.36087653040885925
# Epoch 6, Loss: 0.7497212290763855
# Epoch 10, Loss: 0.2884374260902405
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3922815173110077, feed_forward_dim=256, head_dim=8, lr=0.0032083479827669232, num_heads=4, num_layers=2; total time=   0.4s
# Epoch 7, Loss: 0.6187745928764343
# Epoch 5, Loss: 0.44033166766166687
# Epoch 4, Loss: 0.2667739987373352
# Epoch 8, Loss: 0.33683937788009644
# Epoch 6, Loss: 0.7234182953834534
# Epoch 5, Loss: 0.3205890953540802
# Epoch 9, Loss: 0.1265605092048645
# Epoch 7, Loss: 0.4784780442714691
# Epoch 10, Loss: 0.06226234510540962
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3922815173110077, feed_forward_dim=256, head_dim=8, lr=0.0032083479827669232, num_heads=4, num_layers=2; total time=   0.6s
# Epoch 6, Loss: 0.7665277123451233
# Epoch 8, Loss: 0.19011075794696808
# Epoch 7, Loss: 0.6051281094551086
# Epoch 9, Loss: 0.0587875135242939
# Epoch 8, Loss: 0.2688124179840088
# Epoch 10, Loss: 0.07170673459768295
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3922815173110077, feed_forward_dim=256, head_dim=8, lr=0.0032083479827669232, num_heads=4, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.07621845602989197
# Epoch 10, Loss: 0.06953546404838562
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3922815173110077, feed_forward_dim=256, head_dim=8, lr=0.0032083479827669232, num_heads=4, num_layers=2; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.7332115173339844
# Epoch 2, Loss: 0.6208166480064392
# Epoch 1, Loss: 0.36974698305130005
# Epoch 3, Loss: 0.5271146893501282
# Epoch 1, Loss: 1.7572460174560547
# Epoch 4, Loss: 0.4376441240310669
# Epoch 5, Loss: 0.36810582876205444
# Epoch 2, Loss: 0.302703320980072
# Epoch 1, Loss: 0.9493831992149353
# Epoch 6, Loss: 0.29589900374412537
# Epoch 2, Loss: 1.5630978345870972
# Epoch 1, Loss: 6.170129299163818
# Epoch 7, Loss: 0.2450307160615921
# Epoch 3, Loss: 0.23750567436218262
# Epoch 8, Loss: 0.20769305527210236
# Epoch 2, Loss: 0.7813366055488586
# Epoch 9, Loss: 0.17269814014434814
# Epoch 10, Loss: 0.14918026328086853
# Epoch 4, Loss: 0.19402548670768738
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.14688784996123275, feed_forward_dim=128, head_dim=16, lr=5e-05, num_heads=8, num_layers=3; total time=   0.2s
# Epoch 3, Loss: 1.3761857748031616
# Epoch 2, Loss: 5.808876991271973
# Epoch 5, Loss: 0.15531477332115173
# Epoch 3, Loss: 0.6393640637397766
# Epoch 4, Loss: 1.2028226852416992
# Epoch 6, Loss: 0.13123908638954163
# Epoch 7, Loss: 0.11781613528728485
# Epoch 3, Loss: 5.441033363342285
# Epoch 5, Loss: 1.0373568534851074
# Epoch 4, Loss: 0.5054190754890442
# Epoch 8, Loss: 0.10472340136766434
# Epoch 6, Loss: 0.891170859336853
# Epoch 9, Loss: 0.10576970875263214
# Epoch 5, Loss: 0.38858526945114136
# Epoch 4, Loss: 5.066683292388916
# Epoch 10, Loss: 0.10203870385885239
# Epoch 7, Loss: 0.7497584819793701
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.14688784996123275, feed_forward_dim=128, head_dim=16, lr=5e-05, num_heads=8, num_layers=3; total time=   0.5s
# Epoch 6, Loss: 0.2935854196548462
# Epoch 8, Loss: 0.6358689665794373
# Epoch 5, Loss: 4.726863861083984
# Epoch 7, Loss: 0.216739684343338
# Epoch 9, Loss: 0.5243613719940186
# Epoch 6, Loss: 4.390191555023193
# Epoch 10, Loss: 0.4340190887451172
# Epoch 8, Loss: 0.1495152860879898
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.14688784996123275, feed_forward_dim=128, head_dim=16, lr=5e-05, num_heads=8, num_layers=3; total time=   0.6s
# Epoch 9, Loss: 0.10228954255580902
# Epoch 7, Loss: 4.05734395980835
# Epoch 10, Loss: 0.0656193196773529
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.14688784996123275, feed_forward_dim=128, head_dim=16, lr=5e-05, num_heads=8, num_layers=3; total time=   0.7s
# Epoch 8, Loss: 3.733553171157837
# Epoch 9, Loss: 3.4249958992004395
# Epoch 10, Loss: 3.1371312141418457
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.14688784996123275, feed_forward_dim=128, head_dim=16, lr=5e-05, num_heads=8, num_layers=3; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.8701004385948181
# Epoch 2, Loss: 0.7274265885353088
# Epoch 1, Loss: 0.23883917927742004
# Epoch 3, Loss: 0.6044740676879883
# Epoch 1, Loss: 0.015924619510769844
# Epoch 4, Loss: 0.4810403287410736
# Epoch 2, Loss: 0.17587138712406158
# Epoch 5, Loss: 0.38628536462783813
# Epoch 1, Loss: 0.46161913871765137
# Epoch 3, Loss: 0.11955942213535309
# Epoch 6, Loss: 0.3000262677669525
# Epoch 2, Loss: 0.01739119365811348
# Epoch 1, Loss: 0.2892283797264099
# Epoch 7, Loss: 0.22932235896587372
# Epoch 4, Loss: 0.08495108783245087
# Epoch 8, Loss: 0.18336601555347443
# Epoch 3, Loss: 0.013902949169278145
# Epoch 9, Loss: 0.14205169677734375
# Epoch 5, Loss: 0.059552572667598724
# Epoch 2, Loss: 0.36931711435317993
# Epoch 10, Loss: 0.10723688453435898
# Epoch 2, Loss: 0.20122171938419342
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3953633154594831, feed_forward_dim=512, head_dim=32, lr=5e-05, num_heads=8, num_layers=4; total time=   0.3s
# Epoch 6, Loss: 0.044613905251026154
# Epoch 4, Loss: 0.012938687577843666
# Epoch 7, Loss: 0.04005772992968559
# Epoch 3, Loss: 0.29933616518974304
# Epoch 8, Loss: 0.042733337730169296
# Epoch 5, Loss: 0.01267505157738924
# Epoch 3, Loss: 0.13027404248714447
# Epoch 9, Loss: 0.04752960056066513
# Epoch 4, Loss: 0.24859189987182617
# Epoch 6, Loss: 0.011614888906478882
# Epoch 10, Loss: 0.05130720138549805
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3953633154594831, feed_forward_dim=512, head_dim=32, lr=5e-05, num_heads=8, num_layers=4; total time=   0.4s
# Epoch 4, Loss: 0.07444988191127777
# Epoch 7, Loss: 0.010391163639724255
# Epoch 5, Loss: 0.2122528851032257
# Epoch 8, Loss: 0.009841635823249817
# Epoch 5, Loss: 0.039036598056554794
# Epoch 6, Loss: 0.19309885799884796
# Epoch 9, Loss: 0.010916712693870068
# Epoch 6, Loss: 0.017990348860621452
# Epoch 10, Loss: 0.010256313718855381
# Epoch 7, Loss: 0.1844225525856018
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3953633154594831, feed_forward_dim=512, head_dim=32, lr=5e-05, num_heads=8, num_layers=4; total time=   0.6s
# Epoch 8, Loss: 0.1778237521648407
# Epoch 7, Loss: 0.010866882279515266
# Epoch 9, Loss: 0.18251383304595947
# Epoch 8, Loss: 0.013030843809247017
# Epoch 10, Loss: 0.18173936009407043
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3953633154594831, feed_forward_dim=512, head_dim=32, lr=5e-05, num_heads=8, num_layers=4; total time=   0.8s
# Epoch 9, Loss: 0.020866403356194496
# Epoch 10, Loss: 0.033473365008831024
# [CV] END activation=relu, batch_size=16, dropout_rate=0.3953633154594831, feed_forward_dim=512, head_dim=32, lr=5e-05, num_heads=8, num_layers=4; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 3.3940062522888184
# Epoch 2, Loss: 8.446056365966797
# Epoch 1, Loss: 0.4623408913612366
# Epoch 3, Loss: 2.5308141708374023
# Epoch 1, Loss: 0.1767900586128235
# Epoch 4, Loss: 0.15278932452201843
# Epoch 2, Loss: 11.364706993103027
# Epoch 5, Loss: 0.4533473253250122
# Epoch 6, Loss: 0.7627191543579102
# Epoch 3, Loss: 3.0852911472320557
# Epoch 2, Loss: 2.966723918914795
# Epoch 7, Loss: 0.4795517921447754
# Epoch 1, Loss: 0.24498781561851501
# Epoch 8, Loss: 0.15930812060832977
# Epoch 4, Loss: 0.0683266893029213
# Epoch 1, Loss: 0.16212424635887146
# Epoch 9, Loss: 0.07886867225170135
# Epoch 3, Loss: 0.9989991784095764
# Epoch 10, Loss: 0.15960900485515594
# Epoch 5, Loss: 0.8939303755760193
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.12547022952256598, feed_forward_dim=128, head_dim=16, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.3s
# Epoch 2, Loss: 10.95865249633789
# Epoch 6, Loss: 0.8501242995262146
# Epoch 4, Loss: 0.4085657000541687
# Epoch 2, Loss: 13.618223190307617
# Epoch 7, Loss: 0.33069735765457153
# Epoch 3, Loss: 2.4787800312042236
# Epoch 5, Loss: 0.03845132887363434
# Epoch 8, Loss: 0.07733505219221115
# Epoch 3, Loss: 2.485562562942505
# Epoch 9, Loss: 0.1402106136083603
# Epoch 4, Loss: 0.04040629044175148
# Epoch 6, Loss: 0.1504601389169693
# Epoch 10, Loss: 0.2430524379014969
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.12547022952256598, feed_forward_dim=128, head_dim=16, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.5s
# Epoch 7, Loss: 0.20467917621135712
# Epoch 4, Loss: 0.2897292971611023
# Epoch 5, Loss: 0.714185893535614
# Epoch 8, Loss: 0.13266748189926147
# Epoch 6, Loss: 0.7233677506446838
# Epoch 5, Loss: 0.9127883315086365
# Epoch 9, Loss: 0.06712987273931503
# Epoch 10, Loss: 0.07220339775085449
# Epoch 7, Loss: 0.35716333985328674
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.12547022952256598, feed_forward_dim=128, head_dim=16, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.6s
# Epoch 6, Loss: 0.524657666683197
# Epoch 8, Loss: 0.10375826805830002
# Epoch 7, Loss: 0.14452630281448364
# Epoch 9, Loss: 0.053912993520498276
# Epoch 8, Loss: 0.06038431450724602
# Epoch 10, Loss: 0.1113525778055191
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.12547022952256598, feed_forward_dim=128, head_dim=16, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.8s
# Epoch 9, Loss: 0.15021570026874542
# Epoch 10, Loss: 0.18126553297042847
# [CV] END activation=gelu, batch_size=16, dropout_rate=0.12547022952256598, feed_forward_dim=128, head_dim=16, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.30418819189071655
# Epoch 2, Loss: 8.657960891723633
# Epoch 1, Loss: 0.014036702923476696
# Epoch 3, Loss: 2.42541241645813
# Epoch 4, Loss: 0.07524622976779938
# Epoch 1, Loss: 0.6268503069877625
# Epoch 5, Loss: 0.7586964964866638
# Epoch 2, Loss: 9.907720565795898
# Epoch 1, Loss: 0.12333101779222488
# Epoch 6, Loss: 0.820642352104187
# Epoch 3, Loss: 0.4201045632362366
# Epoch 7, Loss: 0.4212489724159241
# Epoch 1, Loss: 0.04798208922147751
# Epoch 2, Loss: 9.092764854431152
# Epoch 8, Loss: 0.1476532518863678
# Epoch 4, Loss: 2.4069037437438965
# Epoch 9, Loss: 0.06306552141904831
# Epoch 2, Loss: 14.397208213806152
# Epoch 10, Loss: 0.10026481747627258
# Epoch 3, Loss: 3.190946578979492
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.12882142254383877, feed_forward_dim=256, head_dim=32, lr=0.003808690452522345, num_heads=2, num_layers=4; total time=   0.3s
# Epoch 5, Loss: 1.0428807735443115
# Epoch 2, Loss: 7.613419532775879
# Epoch 4, Loss: 0.20666633546352386
# Epoch 3, Loss: 3.3972532749176025
# Epoch 6, Loss: 0.15449641644954681
# Epoch 7, Loss: 0.07767059653997421
# Epoch 5, Loss: 0.5421832799911499
# Epoch 3, Loss: 0.96478670835495
# Epoch 4, Loss: 0.05255640670657158
# Epoch 8, Loss: 0.24392834305763245
# Epoch 6, Loss: 0.8613110184669495
# Epoch 9, Loss: 0.3030970096588135
# Epoch 5, Loss: 0.9891185164451599
# Epoch 7, Loss: 0.5010688900947571
# Epoch 4, Loss: 0.3415168523788452
# Epoch 10, Loss: 0.22737029194831848
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.12882142254383877, feed_forward_dim=256, head_dim=32, lr=0.003808690452522345, num_heads=2, num_layers=4; total time=   0.5s
# Epoch 8, Loss: 0.16468456387519836
# Epoch 6, Loss: 0.9727300405502319
# Epoch 5, Loss: 0.7585166692733765
# Epoch 9, Loss: 0.06153785437345505
# Epoch 7, Loss: 0.43869200348854065
# Epoch 10, Loss: 0.11581600457429886
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.12882142254383877, feed_forward_dim=256, head_dim=32, lr=0.003808690452522345, num_heads=2, num_layers=4; total time=   0.7s
# Epoch 6, Loss: 0.40594321489334106
# Epoch 8, Loss: 0.08788922429084778
# Epoch 7, Loss: 0.11307671666145325
# Epoch 9, Loss: 0.09547843039035797
# Epoch 10, Loss: 0.2572771906852722
# Epoch 8, Loss: 0.056139227002859116
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.12882142254383877, feed_forward_dim=256, head_dim=32, lr=0.003808690452522345, num_heads=2, num_layers=4; total time=   0.9s
# Epoch 9, Loss: 0.12025093287229538
# Epoch 10, Loss: 0.16660292446613312
# [CV] END activation=gelu, batch_size=32, dropout_rate=0.12882142254383877, feed_forward_dim=256, head_dim=32, lr=0.003808690452522345, num_heads=2, num_layers=4; total time=   1.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.19807380437850952
# Epoch 2, Loss: 11.936271667480469
# Epoch 1, Loss: 0.10298920422792435
# Epoch 3, Loss: 0.3001508116722107
# Epoch 1, Loss: 0.5270621180534363
# Epoch 4, Loss: 3.172846555709839
# Epoch 2, Loss: 9.42372989654541
# Epoch 1, Loss: 0.5427173376083374
# Epoch 5, Loss: 1.4084669351577759
# Epoch 1, Loss: 0.7963652014732361
# Epoch 2, Loss: 7.173006534576416
# Epoch 3, Loss: 1.4642342329025269
# Epoch 6, Loss: 0.2832533121109009
# Epoch 7, Loss: 0.0714755728840828
# Epoch 2, Loss: 7.205918312072754
# Epoch 4, Loss: 0.22308005392551422
# Epoch 8, Loss: 0.19210323691368103
# Epoch 3, Loss: 1.4111595153808594
# Epoch 9, Loss: 0.27495792508125305
# Epoch 2, Loss: 12.970785140991211
# Epoch 5, Loss: 0.794202983379364
# Epoch 10, Loss: 0.2372804433107376
# [CV] END activation=relu, batch_size=64, dropout_rate=0.3603328110173327, feed_forward_dim=128, head_dim=32, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.3s
# Epoch 4, Loss: 0.18778930604457855
# Epoch 3, Loss: 1.4712539911270142
# Epoch 6, Loss: 0.537177562713623
# Epoch 5, Loss: 0.7234141826629639
# Epoch 7, Loss: 0.18230237066745758
# Epoch 3, Loss: 3.4309635162353516
# Epoch 4, Loss: 0.11387845128774643
# Epoch 6, Loss: 0.4268960654735565
# Epoch 8, Loss: 0.06568773090839386
# Epoch 9, Loss: 0.12577342987060547
# Epoch 7, Loss: 0.12628380954265594
# Epoch 5, Loss: 0.6268323659896851
# Epoch 4, Loss: 0.06782013922929764
# Epoch 10, Loss: 0.19215427339076996
# [CV] END activation=relu, batch_size=64, dropout_rate=0.3603328110173327, feed_forward_dim=128, head_dim=32, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.5s
# Epoch 8, Loss: 0.0689854621887207
# Epoch 6, Loss: 0.42698168754577637
# Epoch 5, Loss: 0.8869743347167969
# Epoch 9, Loss: 0.13996747136116028
# Epoch 7, Loss: 0.14176110923290253
# Epoch 10, Loss: 0.17753702402114868
# [CV] END activation=relu, batch_size=64, dropout_rate=0.3603328110173327, feed_forward_dim=128, head_dim=32, lr=0.004999999999999999, num_heads=8, num_layers=4; total time=   0.7s
# Epoch 6, Loss: 0.9085598587989807
# Epoch 8, Loss: 0.0545046366751194
# ...
# Epoch 4, Loss: 0.13485684990882874
# Epoch 6, Loss: 0.3790779411792755
# Epoch 9, Loss: 0.06872151046991348
# Epoch 10, Loss: 0.18823368847370148
# Epoch 7, Loss: 0.08157361298799515
# Epoch 5, Loss: 0.2572076916694641
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2630688542264234, feed_forward_dim=128, head_dim=8, lr=0.003789291650196273, num_heads=2, num_layers=3; total time=   0.5s
# Epoch 4, Loss: 0.18081483244895935
# Epoch 8, Loss: 0.09027247875928879
# Epoch 6, Loss: 0.5038584470748901
# Epoch 5, Loss: 0.37531667947769165
# Epoch 9, Loss: 0.18332549929618835
# Epoch 7, Loss: 0.3911748230457306
# Epoch 10, Loss: 0.20587830245494843
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2630688542264234, feed_forward_dim=128, head_dim=8, lr=0.003789291650196273, num_heads=2, num_layers=3; total time=   0.6s
# Epoch 6, Loss: 0.7224265933036804
# Epoch 8, Loss: 0.19019310176372528
# Epoch 7, Loss: 0.5105867981910706
# Epoch 9, Loss: 0.06778272986412048
# Epoch 10, Loss: 0.06399915367364883
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2630688542264234, feed_forward_dim=128, head_dim=8, lr=0.003789291650196273, num_heads=2, num_layers=3; total time=   0.7s
# Epoch 8, Loss: 0.20690107345581055
# Epoch 9, Loss: 0.06601977348327637
# Epoch 10, Loss: 0.089930959045887
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2630688542264234, feed_forward_dim=128, head_dim=8, lr=0.003789291650196273, num_heads=2, num_layers=3; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.2572631239891052
# Epoch 2, Loss: 0.1925296038389206
# Epoch 1, Loss: 0.17098785936832428
# Epoch 3, Loss: 0.1356823891401291
# Epoch 4, Loss: 0.09633662551641464
# Epoch 2, Loss: 0.1536695659160614
# Epoch 1, Loss: 0.6168451905250549
# Epoch 5, Loss: 0.06929957121610641
# Epoch 6, Loss: 0.06150547042489052
# Epoch 1, Loss: 0.03595592826604843
# Epoch 3, Loss: 0.13604429364204407
# Epoch 7, Loss: 0.06011766567826271
# Epoch 2, Loss: 0.502661406993866
# Epoch 8, Loss: 0.06306687742471695
# Epoch 1, Loss: 0.9067267179489136
# Epoch 4, Loss: 0.12014764547348022
# Epoch 9, Loss: 0.0686199739575386
# Epoch 2, Loss: 0.027759142220020294
# Epoch 10, Loss: 0.0717916339635849
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2003069332261902, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.2s
# Epoch 3, Loss: 0.40981370210647583
# Epoch 5, Loss: 0.10767492651939392
# Epoch 6, Loss: 0.09913387149572372
# Epoch 2, Loss: 0.7497519254684448
# Epoch 4, Loss: 0.3329373002052307
# Epoch 3, Loss: 0.025741305202245712
# Epoch 7, Loss: 0.08454062789678574
# Epoch 5, Loss: 0.2629505693912506
# Epoch 8, Loss: 0.07467230409383774
# Epoch 4, Loss: 0.025580182671546936
# Epoch 3, Loss: 0.6103312969207764
# Epoch 9, Loss: 0.06703579425811768
# Epoch 6, Loss: 0.2153848558664322
# Epoch 10, Loss: 0.05717531219124794
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2003069332261902, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.4s
# Epoch 5, Loss: 0.02212345227599144
# Epoch 7, Loss: 0.17396250367164612
# Epoch 4, Loss: 0.49050578474998474
# Epoch 8, Loss: 0.14486807584762573
# Epoch 6, Loss: 0.020006073638796806
# Epoch 5, Loss: 0.37585222721099854
# Epoch 9, Loss: 0.1289253979921341
# Epoch 7, Loss: 0.016898469999432564
# Epoch 10, Loss: 0.11848528683185577
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2003069332261902, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.6s
# Epoch 6, Loss: 0.2823214828968048
# Epoch 8, Loss: 0.01476017851382494
# Epoch 7, Loss: 0.20348086953163147
# Epoch 9, Loss: 0.014079841785132885
# Epoch 10, Loss: 0.012683137319982052
# Epoch 8, Loss: 0.1458750218153
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2003069332261902, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.7s
# Epoch 9, Loss: 0.0999707356095314
# Epoch 10, Loss: 0.06790725886821747
# [CV] END activation=relu, batch_size=64, dropout_rate=0.2003069332261902, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.23821277916431427
# Epoch 2, Loss: 0.18399178981781006
# Epoch 1, Loss: 0.12126472592353821
# Epoch 3, Loss: 0.13733865320682526
# Epoch 4, Loss: 0.11067013442516327
# Epoch 2, Loss: 0.09101180732250214
# Epoch 5, Loss: 0.09564253687858582
# Epoch 1, Loss: 0.8123693466186523
# Epoch 6, Loss: 0.08541439473628998
# Epoch 3, Loss: 0.07169006019830704
# Epoch 1, Loss: 1.2743582725524902
# Epoch 7, Loss: 0.08503491431474686
# Epoch 2, Loss: 0.6615176200866699
# Epoch 1, Loss: 0.25712335109710693
# Epoch 8, Loss: 0.08839891850948334
# Epoch 4, Loss: 0.06426544487476349
# Epoch 9, Loss: 0.08618246018886566
# Epoch 5, Loss: 0.06261466443538666
# Epoch 10, Loss: 0.08189349621534348
# Epoch 2, Loss: 1.1158758401870728
# Epoch 3, Loss: 0.5266247391700745
# [CV] END activation=relu, batch_size=64, dropout_rate=0.4, feed_forward_dim=256, head_dim=8, lr=5e-05, num_heads=8, num_layers=2; total time=   0.3s
# Epoch 6, Loss: 0.06157607212662697
# Epoch 2, Loss: 0.2151404619216919
# Epoch 4, Loss: 0.41303709149360657
# Epoch 7, Loss: 0.06342051178216934
# Epoch 3, Loss: 0.9588894844055176
# Epoch 8, Loss: 0.056340862065553665
# Epoch 5, Loss: 0.3085026443004608
# Epoch 3, Loss: 0.19421808421611786
# Epoch 9, Loss: 0.053145866841077805
# Epoch 4, Loss: 0.8196225166320801
# Epoch 6, Loss: 0.22446151077747345
# Epoch 10, Loss: 0.04604971036314964
# [CV] END activation=relu, batch_size=64, dropout_rate=0.4, feed_forward_dim=256, head_dim=8, lr=5e-05, num_heads=8, num_layers=2; total time=   0.4s
# Epoch 7, Loss: 0.15605242550373077
# Epoch 5, Loss: 0.6953164935112
# Epoch 4, Loss: 0.18008802831172943
# Epoch 8, Loss: 0.10181565582752228
# Epoch 6, Loss: 0.5762389302253723
# Epoch 5, Loss: 0.17129425704479218
# Epoch 9, Loss: 0.060059115290641785
# Epoch 7, Loss: 0.47995513677597046
# Epoch 10, Loss: 0.03418838977813721
# [CV] END activation=relu, batch_size=64, dropout_rate=0.4, feed_forward_dim=256, head_dim=8, lr=5e-05, num_heads=8, num_layers=2; total time=   0.6s
# Epoch 6, Loss: 0.16808323562145233
# Epoch 8, Loss: 0.3923855721950531
# Epoch 7, Loss: 0.16125893592834473
# Epoch 9, Loss: 0.31332042813301086
# Epoch 10, Loss: 0.25039446353912354
# Epoch 8, Loss: 0.15447114408016205
# [CV] END activation=relu, batch_size=64, dropout_rate=0.4, feed_forward_dim=256, head_dim=8, lr=5e-05, num_heads=8, num_layers=2; total time=   0.8s
# Epoch 9, Loss: 0.14613665640354156
# Epoch 10, Loss: 0.1384458839893341
# [CV] END activation=relu, batch_size=64, dropout_rate=0.4, feed_forward_dim=256, head_dim=8, lr=5e-05, num_heads=8, num_layers=2; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 1.1958805322647095
# Epoch 2, Loss: 1.0172935724258423
# Epoch 1, Loss: 0.11254867166280746
# Epoch 3, Loss: 0.8369800448417664
# Epoch 1, Loss: 0.6043605804443359
# Epoch 2, Loss: 0.08359190076589584
# Epoch 4, Loss: 0.6943140625953674
# Epoch 1, Loss: 0.39052537083625793
# Epoch 5, Loss: 0.5534599423408508
# Epoch 2, Loss: 0.4755934774875641
# Epoch 3, Loss: 0.0744398832321167
# Epoch 6, Loss: 0.43299928307533264
# Epoch 1, Loss: 0.034994181245565414
# Epoch 7, Loss: 0.33644041419029236
# Epoch 4, Loss: 0.0689791738986969
# Epoch 8, Loss: 0.24569974839687347
# Epoch 2, Loss: 0.2733748257160187
# Epoch 3, Loss: 0.3683132827281952
# Epoch 9, Loss: 0.1840810924768448
# Epoch 5, Loss: 0.06456948071718216
# Epoch 10, Loss: 0.12670406699180603
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13958192391291555, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.3s
# Epoch 4, Loss: 0.27167803049087524
# Epoch 6, Loss: 0.06188405677676201
# Epoch 2, Loss: 0.020646005868911743
# Epoch 3, Loss: 0.17872682213783264
# Epoch 7, Loss: 0.05640409141778946
# Epoch 5, Loss: 0.18773365020751953
# Epoch 8, Loss: 0.051490284502506256
# Epoch 4, Loss: 0.10370291769504547
# Epoch 3, Loss: 0.017766620963811874
# Epoch 6, Loss: 0.1285410225391388
# Epoch 9, Loss: 0.04477221518754959
# Epoch 10, Loss: 0.03662304952740669
# Epoch 7, Loss: 0.08453763276338577
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13958192391291555, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.4s
# Epoch 5, Loss: 0.056201670318841934
# Epoch 4, Loss: 0.020321529358625412
# Epoch 8, Loss: 0.04963095486164093
# Epoch 6, Loss: 0.026272796094417572
# Epoch 9, Loss: 0.030577978119254112
# Epoch 5, Loss: 0.02230197750031948
# Epoch 7, Loss: 0.01778288558125496
# Epoch 10, Loss: 0.02476712316274643
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13958192391291555, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.6s
# Epoch 6, Loss: 0.01926553063094616
# Epoch 8, Loss: 0.023382803425192833
# Epoch 9, Loss: 0.03617691621184349
# Epoch 7, Loss: 0.015860004350543022
# Epoch 10, Loss: 0.0498945526778698
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13958192391291555, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.8s
# Epoch 8, Loss: 0.012926335446536541
# Epoch 9, Loss: 0.01100162137299776
# Epoch 10, Loss: 0.011333024129271507
# [CV] END activation=relu, batch_size=64, dropout_rate=0.13958192391291555, feed_forward_dim=128, head_dim=8, lr=5e-05, num_heads=2, num_layers=1; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 1.0157289505004883
# Epoch 2, Loss: 0.856553316116333
# Epoch 3, Loss: 0.6913977265357971
# Epoch 1, Loss: 0.05007728189229965
# Epoch 4, Loss: 0.5466191172599792
# Epoch 2, Loss: 0.032565850764513016
# Epoch 5, Loss: 0.4348598122596741
# Epoch 1, Loss: 0.1444198489189148
# Epoch 6, Loss: 0.33167019486427307
# Epoch 7, Loss: 0.2509016692638397
# Epoch 3, Loss: 0.02445521578192711
# Epoch 1, Loss: 0.02621731348335743
# Epoch 1, Loss: 0.1467287838459015
# Epoch 8, Loss: 0.18955841660499573
# Epoch 2, Loss: 0.09964585304260254
# Epoch 9, Loss: 0.14245730638504028
# Epoch 4, Loss: 0.024955114349722862
# Epoch 10, Loss: 0.11494533717632294
# [CV] END activation=relu, batch_size=32, dropout_rate=0.2842351262303144, feed_forward_dim=1024, head_dim=8, lr=5e-05, num_heads=8, num_layers=1; total time=   0.3s
# Epoch 5, Loss: 0.026292096823453903
# Epoch 2, Loss: 0.014232530258595943
# Epoch 3, Loss: 0.06638162583112717
# Epoch 2, Loss: 0.09516941010951996
# Epoch 6, Loss: 0.024680176749825478
# Epoch 4, Loss: 0.044483449310064316
# Epoch 7, Loss: 0.021441377699375153
# Epoch 3, Loss: 0.012255795300006866
# Epoch 8, Loss: 0.016742581501603127
# Epoch 3, Loss: 0.058383502066135406
# Epoch 5, Loss: 0.034519415348768234
# Epoch 9, Loss: 0.012120138853788376
# Epoch 4, Loss: 0.01432710886001587
# Epoch 6, Loss: 0.03529956191778183
# Epoch 10, Loss: 0.010412351228296757
# [CV] END activation=relu, batch_size=32, dropout_rate=0.2842351262303144, feed_forward_dim=1024, head_dim=8, lr=5e-05, num_heads=8, num_layers=1; total time=   0.4s
# Epoch 4, Loss: 0.04077252373099327
# Epoch 5, Loss: 0.014324591495096684
# Epoch 7, Loss: 0.03848731145262718
# Epoch 8, Loss: 0.04280782490968704
# Epoch 5, Loss: 0.035431306809186935
# Epoch 6, Loss: 0.011743323877453804
# Epoch 9, Loss: 0.04762393236160278
# Epoch 7, Loss: 0.009179418906569481
# Epoch 6, Loss: 0.04005492106080055
# Epoch 10, Loss: 0.04970025643706322
# [CV] END activation=relu, batch_size=32, dropout_rate=0.2842351262303144, feed_forward_dim=1024, head_dim=8, lr=5e-05, num_heads=8, num_layers=1; total time=   0.6s
# Epoch 8, Loss: 0.0066728657111525536
# Epoch 7, Loss: 0.04746520146727562
# Epoch 9, Loss: 0.006266260053962469
# Epoch 8, Loss: 0.05206894129514694
# Epoch 10, Loss: 0.0072276839055120945
# [CV] END activation=relu, batch_size=32, dropout_rate=0.2842351262303144, feed_forward_dim=1024, head_dim=8, lr=5e-05, num_heads=8, num_layers=1; total time=   0.8s
# Epoch 9, Loss: 0.05346488207578659
# Epoch 10, Loss: 0.049422234296798706
# [CV] END activation=relu, batch_size=32, dropout_rate=0.2842351262303144, feed_forward_dim=1024, head_dim=8, lr=5e-05, num_heads=8, num_layers=1; total time=   0.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Epoch 1, Loss: 0.9549704194068909
# Epoch 2, Loss: 0.186329185962677
# Epoch 3, Loss: 0.08804918825626373
# Epoch 1, Loss: 0.4142879247665405
# Epoch 4, Loss: 0.26572519540786743
# Epoch 2, Loss: 0.10181442648172379
# Epoch 5, Loss: 0.3342030346393585
# Epoch 1, Loss: 0.17383867502212524
# Epoch 6, Loss: 0.25443708896636963
# Epoch 3, Loss: 0.1063767820596695
# Epoch 7, Loss: 0.12892118096351624
# Epoch 1, Loss: 1.413176417350769
# Epoch 8, Loss: 0.041484933346509933
# Epoch 2, Loss: 0.04121902585029602
# Epoch 4, Loss: 0.16988223791122437
# Epoch 1, Loss: 0.10936000198125839
# Epoch 9, Loss: 0.013905600644648075
# Epoch 10, Loss: 0.03840529918670654
# Epoch 5, Loss: 0.15242893993854523
# Epoch 2, Loss: 0.5348337888717651
# [CV] END activation=relu, batch_size=32, dropout_rate=0.12328754191935205, feed_forward_dim=256, head_dim=32, lr=0.0003001523187768401, num_heads=4, num_layers=4; total time=   0.3s
# Epoch 3, Loss: 0.12671130895614624
# Epoch 6, Loss: 0.09089315682649612
# Epoch 2, Loss: 0.14844200015068054
# Epoch 4, Loss: 0.07206586748361588
# Epoch 7, Loss: 0.03690461441874504
# Epoch 3, Loss: 0.14339329302310944
# Epoch 8, Loss: 0.019172867760062218
# Epoch 5, Loss: 0.01598786748945713
# Epoch 9, Loss: 0.0328226163983345
# Epoch 3, Loss: 0.0800786092877388
# Epoch 4, Loss: 0.13876397907733917
# Epoch 6, Loss: 0.025623030960559845
# Epoch 10, Loss: 0.05414814502000809
# [CV] END activation=relu, batch_size=32, dropout_rate=0.12328754191935205, feed_forward_dim=256, head_dim=32, lr=0.0003001523187768401, num_heads=4, num_layers=4; total time=   0.4s
# Epoch 5, Loss: 0.2903680205345154
# Epoch 7, Loss: 0.054470039904117584
# Epoch 4, Loss: 0.033701956272125244
# Epoch 8, Loss: 0.05547941103577614
# Epoch 6, Loss: 0.3753519356250763
# Epoch 5, Loss: 0.057702552527189255
# Epoch 9, Loss: 0.029307158663868904
# Epoch 7, Loss: 0.3606582283973694
# Epoch 10, Loss: 0.00982169434428215
# [CV] END activation=relu, batch_size=32, dropout_rate=0.12328754191935205, feed_forward_dim=256, head_dim=32, lr=0.0003001523187768401, num_heads=4, num_layers=4; total time=   0.6s
# Epoch 6, Loss: 0.05645108222961426
# Epoch 8, Loss: 0.27501219511032104
# Epoch 9, Loss: 0.17815563082695007
# Epoch 7, Loss: 0.026398126035928726
# Epoch 10, Loss: 0.09773404151201248
# [CV] END activation=relu, batch_size=32, dropout_rate=0.12328754191935205, feed_forward_dim=256, head_dim=32, lr=0.0003001523187768401, num_heads=4, num_layers=4; total time=   0.7s
# Epoch 8, Loss: 0.013022170402109623
# Epoch 9, Loss: 0.02671525999903679
# Epoch 10, Loss: 0.03537244722247124
# [CV] END activation=relu, batch_size=32, dropout_rate=0.12328754191935205, feed_forward_dim=256, head_dim=32, lr=0.0003001523187768401, num_heads=4, num_layers=4; total time=   0.9s
# Epoch 1, Loss: 0.44784536957740784
# Epoch 2, Loss: 0.3045455515384674
# Epoch 3, Loss: 0.19000627100467682
# Epoch 4, Loss: 0.11101784557104111
# Epoch 5, Loss: 0.06273573637008667
# Epoch 6, Loss: 0.04217538982629776
# Epoch 7, Loss: 0.04319222271442413
# Epoch 8, Loss: 0.05618204176425934
# Epoch 9, Loss: 0.07231598347425461
# Epoch 10, Loss: 0.08592398464679718
# BayesSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#               estimator=TFTEstimator(), n_jobs=-1, random_state=42,
#               scoring='neg_mean_absolute_error',
#               search_spaces={'activation': Categorical(categories=('relu', 'gelu'), prior=None),
#                              'batch_size': Categorical(categories=(16, 32, 64), prior=None),
#                              'dropout_rate': Real(low=0.1, high=0.4, prio...transform='normalize'),
#                              'feed_forward_dim': Categorical(categories=(128, 256, 512, 1024), prior=None),
#                              'head_dim': Categorical(categories=(8, 16, 32), prior=None),
#                              'lr': Real(low=5e-05, high=0.005, prior='log-uniform', transform='normalize'),
#                              'num_heads': Categorical(categories=(2, 4, 8), prior=None),
#                              'num_layers': Categorical(categories=(1, 2, 3, 4), prior=None)},
#               verbose=2)

# %%
# Get the best estimator and its parameters
best_estimator = bayes_search.best_estimator_
best_params = bayes_search.best_params_
best_score = -bayes_search.best_score_

# Define the hyperparameters relevant for the wrapper
wrapper_hyperparams = ['look_back', 'num_heads', 'head_dim', 'feed_forward_dim', 
                       'dropout_rate', 'num_layers', 'activation', 'n_steps_ahead']

# Extract only the relevant parameters for the wrapper
filtered_params = {key: value for key, value in bayes_search.best_params_.items() if key in wrapper_hyperparams}

# Update the model_params of the best estimator
best_estimator.model_params.update(filtered_params)

# Reinitialize the model with the updated parameters
best_estimator.model = Seq2SeqTemporalFusionTransformerWrapper(**best_estimator.model_params)

# Confirm the synchronization
print("Updated model_params:", best_estimator.model_params)
# Out:
# Updated model_params: {'look_back': 7, 'num_heads': 8, 'head_dim': 16, 'feed_forward_dim': 1024, 'dropout_rate': 0.27941412325363846, 'num_layers': 4, 'activation': 'gelu', 'n_steps_ahead': 3}

# %%
# # Remove unwanted keys from model_params
# unwanted_keys = ['batch_size', 'lr']

# # Remove unwanted keys from model_params
# for key in unwanted_keys:
#     best_estimator.model_params.pop(key, None)  # Use pop to avoid KeyError if the key is missing

# # Check the updated model_params
# print("Cleaned model_params:", best_estimator.model_params)

# %%
# Save best model
# Save the BayesSearchCV wrapper
joblib.dump(best_estimator, '../models/lookback7/best_tft_estimator.pkl')

# Save the PyTorch model inside the wrapper
torch.save(best_estimator.model.state_dict(), '../models/lookback7/best_tft_model.pth')

# Save best hyperparameters
joblib.dump(best_params, '../models/lookback7/best_tft_params.pkl')

# Save best score
with open('../models/lookback7/best_tft_score.txt', 'w') as f:
    f.write(str(best_score))

# %%
# Load best_params
best_params = joblib.load('../models/lookback7/best_tft_params.pkl')

# Initialize the model with the best hyperparameters
best_model = Seq2SeqTemporalFusionTransformerWrapper(
    look_back=7,
    num_heads=best_params['num_heads'],
    head_dim=best_params['head_dim'],
    feed_forward_dim=best_params['feed_forward_dim'],
    dropout_rate=best_params['dropout_rate'],
    num_layers=best_params['num_layers'],
    activation=best_params['activation'],
    n_steps_ahead=3
)

# Load the state_dict
checkpoint = torch.load('../models/lookback7/best_tft_model.pth', weights_only=True)

# # If state_dict contains extra keys, filter them
# if 'model_state_dict' in checkpoint:
#     state_dict = checkpoint['model_state_dict']  # Extract the actual model weights
# else:
#     state_dict = checkpoint  # Use the raw state_dict if no wrapper keys exist

# Load the weights into the model
best_model.load_state_dict(checkpoint)

# Set the model to evaluation mode
best_model.eval()
# Out:
# Seq2SeqTemporalFusionTransformerWrapper(
#   (model): Seq2SeqTemporalFusionTransformer(
#     (input_projection): Linear(in_features=1, out_features=128, bias=True)
#     (positional_encoding): PositionalEncoding()
#     (activation_fn): GELU(approximate='none')
#     (encoder_layers): ModuleList(
#       (0-3): 4 x ModuleDict(
#         (multi_head_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (layer_norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (feed_forward): Sequential(
#           (0): Linear(in_features=128, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.27941412325363846, inplace=False)
#           (3): Linear(in_features=1024, out_features=128, bias=True)
#         )
#         (layer_norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (decoder_layers): ModuleList(
#       (0-3): 4 x ModuleDict(
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (cross_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (layer_norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (feed_forward): Sequential(
#           (0): Linear(in_features=128, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.27941412325363846, inplace=False)
#           (3): Linear(in_features=1024, out_features=128, bias=True)
#         )
#         (layer_norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (output_layer): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ### Prediction on Test Set

# %%
# Make predictions
y_pred = best_model.predict(X_test)

# Inverse transform the predictions
y_pred_inverse = scaler.inverse_transform(y_pred)
y_test_inverse = scaler.inverse_transform(y_test)

# Evaluate the predictions
mse = root_mean_squared_error(y_test_inverse, y_pred_inverse)
mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
mape = mean_absolute_percentage_error(y_test_inverse, y_pred_inverse)

# Print the results
print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")

# save metrics as dataframe and save to csv
metrics = pd.DataFrame({'MSE': [mse], 'MAE': [mae], 'MAPE': [mape]})
# metrics.to_csv('../results/metrics/lookback7/tft_seq2seq_metrics.csv', index=False)

# Save the predictions as .npy file
# np.save('../results/predictions/test/lookback7/tft_seq2seq_predictions.npy', y_pred_inverse)
# Out:
# Mean Squared Error (MSE): 3.6747539043426514
# Mean Absolute Error (MAE): 3.6473166942596436
# Mean Absolute Percentage Error (MAPE): 24.73586082458496

# %%
# plot y_pred vs y_test
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
plt.plot(y_test_inverse, label='True', marker='o')
plt.plot(y_pred_inverse, label='Predicted', marker='x')
plt.title("True vs Predicted")
plt.legend()
plt.grid()
# plt.savefig('../results/plots/test/lookback7/tft_seq2seq_plot.png')
plt.show()

# %% [markdown]
# ### Save the model weights and optimizer

# %%
# import matplotlib.pyplot as plt

# plt.figure(figsize=(40, 6))
# # plt.plot(y_test, label="True Values")
# plt.plot(y_pred, label="Predicted Values")
# plt.legend()
# plt.title("True vs Predicted Values")
# plt.xlabel("Sample Index")
# plt.ylabel("Value")
# plt.show()

# %% [markdown]
# ### Load back model

# %%
future_days = 10

recent_data = X_test[-1].reshape(1, -1, 1)
recent_data = torch.tensor(recent_data, dtype=torch.float32)

# Make predictions
predictions = []
for _ in range(future_days):
    # with torch.no_grad():
    #     prediction = best_model(recent_data)
    prediction = best_model.predict(recent_data.numpy())
    
    # Append the first predicted value to the list
    # predictions.append(prediction[:, 0].squeeze(-1).cpu().numpy())  # Take the first value
    
    # Update the recent_data for the next prediction
    # recent_data = torch.cat([recent_data[:, 1:, :], prediction[:, 0].unsqueeze(1).unsqueeze(-1)], dim=1)
    # Append the first predicted value
    predictions.append(prediction[0, 0])  # Take the first value in n_steps_ahead

    # Update recent_data for the next prediction
    next_value = torch.tensor([[prediction[0, 0]]], dtype=torch.float32).unsqueeze(-1)  # Shape: (1, 1, 1)
    recent_data = torch.cat([recent_data[:, 1:, :], next_value], dim=1)  # Slide window forward


# Convert predictions list to numpy array
predictions = np.array(predictions).reshape(-1, 1)

# Inverse transform the predictions
predictions_inverse = scaler.inverse_transform(predictions).flatten()

# Print the predictions
print("Predictions (Inverse Transformed):", predictions_inverse)
# Out:
# Predictions (Inverse Transformed): [-1.8030746 -1.6808653 -1.5390415 -1.3893639 -1.2512403 -1.1455853
#  -1.0553834 -0.9782003 -0.9949461 -1.0092064]

# %%
future_days = 10

# Get the most recent data
recent_data = X_test[-1].reshape(1, -1, 1)  # Shape: (1, look_back, 1)
recent_data = torch.tensor(recent_data, dtype=torch.float32)

# Initialize a single list to store all predictions
predictions = []  # This will store predictions for all 3 cases

# Make predictions
for _ in range(future_days):
    with torch.no_grad():
        # Predict the next `n_steps_ahead` days
        prediction = loaded_model(recent_data)  # Shape: (1, n_steps_ahead)
    
    # Append all predicted values to the predictions list
    predictions.append(prediction.squeeze().tolist())  # Shape: (n_steps_ahead,)
    
    # Update recent_data for each case
    # Case 1: Update with the first predicted value
    recent_data_1 = torch.cat([recent_data[:, 1:, :], prediction[:, 0].unsqueeze(1).unsqueeze(-1)], dim=1)
    
    # Case 2: Update with the second predicted value
    recent_data_2 = torch.cat([recent_data[:, 1:, :], prediction[:, 1].unsqueeze(1).unsqueeze(-1)], dim=1)
    
    # Case 3: Update with the third predicted value
    recent_data_3 = torch.cat([recent_data[:, 1:, :], prediction[:, 2].unsqueeze(1).unsqueeze(-1)], dim=1)
    
    # For the next iteration, use the updated recent_data for each case
    recent_data = recent_data_1  # Or recent_data_2 or recent_data_3, depending on which case you want to continue

# Convert predictions list to a numpy array
predictions = np.array(predictions)  # Shape: (future_days, n_steps_ahead)

# Inverse transform the predictions
predictions_inverse = scaler.inverse_transform(predictions)  # Shape: (future_days, n_steps_ahead)

# Split the inverse-transformed predictions into 3 separate arrays
predictions_1_inverse = predictions_inverse[:, 0]  # First predicted value
predictions_2_inverse = predictions_inverse[:, 1]  # Second predicted value
predictions_3_inverse = predictions_inverse[:, 2]  # Third predicted value

# %%
import importlib.util
import sys

module_name = "arima_garch_forecast"
module_path = "/Users/binnu/Library/CloudStorage/OneDrive-student.vgu.edu.vn/VGU/Current Program/Project/Bitcoin Prediction/src/utils/prediction.py"

# Load the module
spec = importlib.util.spec_from_file_location(module_name, module_path)
module = importlib.util.module_from_spec(spec)
sys.modules[module_name] = module
spec.loader.exec_module(module)

# %%
test_pca_df = pd.read_csv("../data/final/test_pca_df.csv", parse_dates=["Date"], index_col="Date")
val_pca_df = pd.read_csv("../data/final/val_pca_df.csv", parse_dates=["Date"], index_col="Date")
val_exog = val_pca_df.drop(columns=["btc_close"])
test_exog = test_pca_df.drop(columns=["btc_close"])
# concat val and test exog
exog = pd.concat([val_exog, test_exog])

arimax_garch_future = module.arima_garch_forecast(exog, '../models', future_days)

# %%
last_date = test_residuals_df.index[-1]

# Undo log-transform (ARIMA-GARCH predictions + TFT predictions)
final_predictions = []

for i in range(3):
    final_predictions.append(np.exp(predictions_inverse[:, i] + arimax_garch_future) - 1)

future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=len(final_predictions[0]))

# Create the DataFrame of future predictions
df_predictions =  pd.DataFrame(final_predictions).T  # Transpose to make each array a column

# Rename the index to 'Day' for clarity
df_predictions.index = future_dates

df_predictions.columns = ['Forecast Price (Case 1)', 'Forecast Price (Case 2)', 'Forecast Price (Case 3)']

# %%
test_actual_values = np.exp(test_pca_df["btc_close"]) - 1
test_arima_garch_pred = test_residuals_df["SARIMA-GARCH Prediction"]
test_arima_garch_pred_org = np.exp(test_arima_garch_pred) - 1
# load np.save('../results/predictions/test/lookback7/tft_seq2seq_predictions.npy', y_pred_inverse)
test_tft_pred = np.load('../results/predictions/test/lookback7/tft_seq2seq_predictions.npy')

test_tft_pred_list = []
combined_test_pred_list = []
combined_test_pred_org_list = []

for i in range(3):
    test_tft_pred_list.append(test_tft_pred[:, i])
    combined_test_pred = test_arima_garch_pred[look_back+2:] + test_tft_pred_list[i]
    combined_test_pred_list.append(combined_test_pred)
    combined_test_pred_org_list.append(np.exp(combined_test_pred) - 1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(test_pca_df.index, test_actual_values, label="Actual Values", color="black")
plt.plot(test_pca_df.index,test_arima_garch_pred_org, label="SARIMA-GARCH Forecast", color="grey")
for i in range(3):
    plt.plot(combined_test_pred_org_list[i], label=f"Predicted Values (Case {i + 1})")
plt.plot(df_predictions.index, df_predictions["Forecast Price (Case 1)"], label="Forecast Price (Case 1)", color="blue")
plt.plot(df_predictions.index, df_predictions["Forecast Price (Case 2)"], label="Forecast Price (Case 2)", color="red")
plt.plot(df_predictions.index, df_predictions["Forecast Price (Case 3)"], label="Forecast Price (Case 3)", color="green")

plt.title("Forecast Comparison on Test Set")
plt.xlabel("Date")
plt.ylabel("BTC Close Price")
plt.legend()
plt.grid()
# plt.savefig("../results/images/test/merge.png")
plt.show()
plt.close()
